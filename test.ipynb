# %%
import pandas as pd
import matplotlib.pyplot as plt
df=pd.read_csv('data.csv')
nrows,ncols=len(df.keys()),1
plt.figure(figsize=(10,5*nrows))
for i,key in enumerate(df.keys(),start=1):
    plt.subplot(nrows,ncols,i)
    plt.plot(df[str(key)])
    plt.title(key)
plt.tight_layout()
plt.show()
