# %%
import pandas as pd
import numpy as np
from calculator import *

# %%
data = pd.read_csv("arsenic.csv")

# %%
data.head()
# Out:
#   StateWellNumber    County AquiferCode  WellDepth        Date    Time  \
# 0         3458904  Anderson     124WLCX     1032.0   4/27/1993  1415.0
# 1         3458904  Anderson     124WLCX     1032.0   5/20/1998  1212.0
# 2         3458904  Anderson     124WLCX     1032.0   3/12/2002  1530.0
# 3         3458904  Anderson     124WLCX     1032.0  10/26/2005  1130.0
# 4         3458904  Anderson     124WLCX     1032.0   4/23/2010  1005.0
#
#    SampleNumber  EntityId  LabId  ReliabilityId  \
# 0           1.0       1.0    1.0            7.0
# 1           1.0       1.0   23.0            7.0
# 2           1.0       1.0   23.0            7.0
# 3           1.0       1.0   24.0            7.0
# 4           1.0       1.0   23.0            7.0
#
#                                    CollectionRemarks  LatitudeDD  LongitudeDD  \
# 0                               Analysis Balanced.     32.016103   -95.751856
# 1                               Analysis Balanced.     32.016103   -95.751856
# ...

# %%
a = pre_process(data,[0,3,6,100],["zero","moderate",'high'])
a
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /var/folders/f1/ptxl35314mj1csv1q3j0_9740000gn/T/ipykernel_3767/63495640.py in <module>
# ----> 1 a = pre_process(data,[0,3,6,100],["zero","moderate",'high'])
#       2 a
#
# ~/Desktop/UROP_Data/UROP_new/UROP/calculator.py in pre_process(data, value_partition, names)
#      22         data.loc[(data['ParameterValue']<upb) & (data['ParameterValue']>=lwb),'type'] = names[i]
#      23         df = pd.DataFrame(data[data['type']==names[i]])
# ---> 24         data_to_return.add(df)
#      25
#      26     #return
#
# TypeError: unhashable type: 'DataFrame'

# %%
a.shape
# Out:
# (2545, 4)
