# %%
import pandas as pd
import numpy as np
from calculator import *

# %%
data = pd.read_csv("arsenic.csv")

# %%
data.head()
# Out:
#   StateWellNumber   County AquiferCode  WellDepth      Date  Time  \
# 0         5846410  Bastrop     124SMBR       45.0  9/3/1980   NaN
# 1         5846502  Bastrop     124SMBR      177.0  9/3/1980   NaN
# 2         5846515  Bastrop     124HOOP      505.0  9/3/1980   NaN
# 3         5854103  Bastrop     124SMBR      152.0  9/3/1980   NaN
# 4         5854302  Bastrop     124SMBR      500.0  9/3/1980   NaN
#
#    SampleNumber  EntityId  LabId  ReliabilityId CollectionRemarks  LatitudeDD  \
# 0           1.0       3.0    2.0           13.0                     30.303056
# 1           1.0       3.0    2.0           13.0                     30.328889
# 2           1.0       3.0    2.0           13.0                     30.321667
# 3           1.0       3.0    2.0           13.0                     30.249722
# 4           1.0       3.0    2.0           13.0                     30.242778
#
#    LongitudeDD  ParameterCode             ParameterDescription ParameterFlag  \
# ...

# %%
df = pre_process(data,[0,3,6,100],["zero","moderate",'high'])
df
# Out:
#      StateWellNumber      Date  LatitudeDD  LongitudeDD  ParameterValue  type
# 1227         5846502  19800309   30.328889   -97.309445             1.0  zero
# 1249         5854302  19800309   30.242778   -97.285556             0.0  zero
# 1248         5854103  19800309   30.249722   -97.346667             0.0  zero
# 1253         5854504  19800309   30.203334   -97.304445             1.0  zero
# 1236         5846515  19800309   30.321667   -97.313889             0.0  zero
# ...              ...       ...         ...          ...             ...   ...
# 1245         5848114  20202907   30.368219   -97.114633             1.0  zero
# 1278         5856302  20202907   30.238397   -97.035461             1.0  zero
# 1212         5839922  20203007   30.407772   -97.149431             1.0  zero
# 1501         6715606  20203007   29.830064   -97.153531             1.0  zero
# 1214         5839923  20203007   30.407689   -97.149139             1.0  zero
#
# [2545 rows x 6 columns]

# %%
df['type'].unique()
# Out:
# array(['zero', 'high', 'moderate'], dtype=object)

# %%
len('27')
# Out:
# 2

# %%
'0'+a.split('/')[0]
# Out:
# '09'
