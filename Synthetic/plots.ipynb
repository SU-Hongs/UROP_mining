# %%
import matplotlib.pyplot as plt
import pandas as pd

path='data/simu_data001.csv'
data=pd.read_csv(path)
plt.figure(figsize=(20,10))
plt.plot(data['A'],label='A')
plt.plot(data['B'],label='B')
plt.plot(data['AB'],label='AB')
plt.legend()
plt.show()
