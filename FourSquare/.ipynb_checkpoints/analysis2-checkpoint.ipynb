# %%
import pandas as pd
import numpy as np
from numpy import random
from math import pi
import turtle as tt
import matplotlib.cm as cm
from tqdm import tqdm
import matplotlib.pyplot as plt
import statsmodels.api
import pandas as pd
import pingouin as pg
from statsmodels.tsa.stattools import *
from statsmodels.tsa.stattools import grangercausalitytests
from statsmodels.tsa.stattools import adfuller
from sklearn import linear_model
import sys
sys.path.append("../groundwater")
from calculator import *
# Out:
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/outdated/utils.py:18: OutdatedPackageWarning: The package pingouin is out of date. Your version is 0.5.1, the latest is 0.5.2.
# Set the environment variable OUTDATED_IGNORE=1 to disable these warnings.
#   **kwargs

# %%
data_colo = pd.read_csv("./dataset_tsmc2014/dataset_TSMC2014_NYC_processed2.csv")
data_colo = data_colo.drop(data_colo.iloc[:,[0]],axis=1)
data_mpi = pd.read_csv("./dataset_tsmc2014/dataset_TSMC2014_NYC_mpi.csv")
data_mpi = data_mpi.drop(data_mpi.iloc[:,[0]],axis=1)
# start_t = 108
# end_t = 252
# data_colo = data_colo.iloc[start_t:end_t+1]
# data_mpi = data_mpi.iloc[start_t:end_t+1]

# %%
print(data_colo.shape)
data_colo.head()
# Out:
# (288, 49)
#    Alcoholic-Related Place  Bank  Beauty, Cosmetology & Hairdressing  Bridge  \
# 0                      1.0  10.0                                22.0    12.0
# 1                      1.0   0.0                                10.0     8.0
# 2                      2.0   6.0                                20.0     2.0
# 3                      2.0   3.0                                10.0     9.0
# 4                      0.0   5.0                                10.0     4.0
#
#    Castle  Clothing & Jewelry  Convention Center  Design Studio  Electronics  \
# 0     0.0                19.0                3.0            0.0          7.0
# 1     0.0                13.0                1.0            1.0          4.0
# 2     0.0                15.0                2.0            0.0          4.0
# 3     0.0                 7.0                1.0            0.0          7.0
# 4     0.0                24.0                1.0            0.0          7.0
#
#    Embassy / Consulate  ...  School  Shop Related to Entertainment  \
# 0                  1.0  ...    25.0                            5.0
# 1                  0.0  ...    20.0                            4.0
# 2                  1.0  ...    17.0                            0.0
# 3                  1.0  ...    20.0                            1.0
# 4                  0.0  ...    22.0                            2.0
#
#    Smoke Shop  Sporting Goods Shop  Storage Facility  Store, Market & Fair  \
# 0         0.0                  3.0               0.0                  28.0
# 1         1.0                  3.0               0.0                  24.0
# 2         3.0                  9.0               1.0                  23.0
# 3         9.0                  2.0               0.0                  25.0
# 4         9.0                  2.0               0.0                  23.0
#
#    Transportation  Travel-Related Place  Vehicle Shop  Vehicle-Related Place
# 0           124.0                   5.0           1.0                    5.0
# 1           122.0                   4.0           1.0                   11.0
# 2           102.0                   3.0           1.0                   12.0
# 3           111.0                   1.0           3.0                   14.0
# 4           111.0                   2.0           2.0                    9.0
#
# [5 rows x 49 columns]

# %%
print(data_mpi.shape)
data_mpi.head()
# Out:
# (288, 49)
#    Alcoholic-Related Place      Bank  Beauty, Cosmetology & Hairdressing  \
# 0                 0.025641  0.014903                            0.019820
# 1                 0.025641  0.000000                            0.009083
# 2                 0.051282  0.008942                            0.018939
# 3                 0.051282  0.002981                            0.009242
# 4                 0.000000  0.007452                            0.009009
#
#      Bridge  Castle  Clothing & Jewelry  Convention Center  Design Studio  \
# 0  0.088889     0.0            0.015794           0.046875       0.000000
# 1  0.066667     0.0            0.012150           0.015625       0.022727
# 2  0.022222     0.0            0.014205           0.031250       0.000000
# 3  0.088889     0.0            0.006542           0.015625       0.000000
# 4  0.044444     0.0            0.022706           0.015625       0.000000
#
#    Electronics  Embassy / Consulate  ...    School  \
# 0     0.026415                 0.05  ...  0.016337
# 1     0.015094                 0.00  ...  0.017257
# 2     0.011321                 0.05  ...  0.014617
# 3     0.022642                 0.05  ...  0.017560
# 4     0.022642                 0.00  ...  0.018921
#
#    Shop Related to Entertainment  Smoke Shop  Sporting Goods Shop  \
# 0                       0.015291    0.000000             0.028571
# 1                       0.012232    0.034483             0.028571
# 2                       0.000000    0.034483             0.066667
# 3                       0.003058    0.068966             0.019048
# 4                       0.006116    0.034483             0.019048
#
#    Storage Facility  Store, Market & Fair  Transportation  \
# 0          0.000000              0.053763        0.096426
# 1          0.000000              0.043011        0.105359
# 2          0.166667              0.040860        0.092803
# 3          0.000000              0.049462        0.097043
# 4          0.000000              0.043011        0.099338
#
#    Travel-Related Place  Vehicle Shop  Vehicle-Related Place
# 0              0.022321      0.002762               0.009709
# 1              0.017857      0.002762               0.021359
# 2              0.013393      0.002762               0.023301
# 3              0.004464      0.008287               0.027184
# 4              0.008929      0.005525               0.015534
#
# [5 rows x 49 columns]

# %%
mPIs = data_mpi.mean(axis=0)
mPIs
# Out:
# Alcoholic-Related Place               0.013177
# Bank                                  0.011990
# Beauty, Cosmetology & Hairdressing    0.011386
# Bridge                                0.044550
# Castle                                0.006944
# Clothing & Jewelry                    0.012641
# Convention Center                     0.018934
# Design Studio                         0.010022
# Electronics                           0.017002
# Embassy / Consulate                   0.006424
# Factory                               0.015873
# Financial or Legal Service            0.006173
# Food & Snack                          0.081951
# Funeral                               0.014290
# Furniture / Home Store                0.014113
# General Education Place               0.018099
# Government Building                   0.013596
# Hardware Store                        0.011811
# History, Museum & Arts                0.018953
# Hotel                                 0.025949
# Indoor Entertainment                  0.172439
# Laundry Service                       0.009378
# Medical-Related Place                 0.027660
# Miscellaneous Shop                    0.011008
# Neighborhood                          0.045807
# Newsstand                             0.004630
# Office                                0.053717
# Outdoor Entertainment                 0.063232
# Paper / Office Supplies Store         0.008878
# Pet-Related Place                     0.010330
# Place for Socializing                 0.009804
# Place for Sports                      0.057970
# Post Office                           0.013016
# Professional & Other Places           0.009958
# Recycling Facility                    0.048611
# Religion & Spirituality               0.012915
# Residence                             0.119571
# Rest Area                             0.015635
# Restaurant                            0.150977
# School                                0.031826
# Shop Related to Entertainment         0.007891
# Smoke Shop                            0.018558
# Sporting Goods Shop                   0.012855
# Storage Facility                      0.008102
# Store, Market & Fair                  0.026384
# Transportation                        0.119841
# Travel-Related Place                  0.015913
# Vehicle Shop                          0.007697
# Vehicle-Related Place                 0.014373
# dtype: float64

# %%
avg_mpi=mPIs.mean()
print('average modified PI:',avg_mpi)
med_mpi=mPIs.median()
print('median modified PI:',med_mpi)
# prevalent_mpi=mPIs[mPIs>avg_mpi]
prevalent_mpi=mPIs[mPIs>med_mpi]
prevalent_mpi
# Out:
# average modified PI: 0.030262313241750924
# median modified PI: 0.014289529914529895
# Bridge                     0.044550
# Convention Center          0.018934
# Electronics                0.017002
# Factory                    0.015873
# Food & Snack               0.081951
# General Education Place    0.018099
# History, Museum & Arts     0.018953
# Hotel                      0.025949
# Indoor Entertainment       0.172439
# Medical-Related Place      0.027660
# Neighborhood               0.045807
# Office                     0.053717
# Outdoor Entertainment      0.063232
# Place for Sports           0.057970
# Recycling Facility         0.048611
# Residence                  0.119571
# Rest Area                  0.015635
# Restaurant                 0.150977
# School                     0.031826
# Smoke Shop                 0.018558
# Store, Market & Fair       0.026384
# Transportation             0.119841
# Travel-Related Place       0.015913
# Vehicle-Related Place      0.014373
# dtype: float64

# %%
prevalenet_mpi_df=prevalent_mpi.to_frame(name='average modified PI')
prevalent_colo=prevalenet_mpi_df.index.values
print(prevalent_colo)
prevalent_colo=prevalent_colo[(prevalent_colo!='Recycling Facility') & (prevalent_colo!='Bridge')]
print(prevalent_colo)
data_colo=data_colo.filter(items=prevalent_colo)
data_mpi=data_mpi.filter(items=prevalent_colo)
# Out:
# ['Bridge' 'Convention Center' 'Electronics' 'Factory' 'Food & Snack'
#  'General Education Place' 'History, Museum & Arts' 'Hotel'
#  'Indoor Entertainment' 'Medical-Related Place' 'Neighborhood' 'Office'
#  'Outdoor Entertainment' 'Place for Sports' 'Recycling Facility'
#  'Residence' 'Rest Area' 'Restaurant' 'School' 'Smoke Shop'
#  'Store, Market & Fair' 'Transportation' 'Travel-Related Place'
#  'Vehicle-Related Place']
# ['Convention Center' 'Electronics' 'Factory' 'Food & Snack'
#  'General Education Place' 'History, Museum & Arts' 'Hotel'
#  'Indoor Entertainment' 'Medical-Related Place' 'Neighborhood' 'Office'
#  'Outdoor Entertainment' 'Place for Sports' 'Residence' 'Rest Area'
#  'Restaurant' 'School' 'Smoke Shop' 'Store, Market & Fair'
#  'Transportation' 'Travel-Related Place' 'Vehicle-Related Place']

# %%
data_colo.head()
# Out:
#    Convention Center  Electronics  Factory  Food & Snack  \
# 0                3.0          7.0      1.0          61.0
# 1                1.0          4.0      1.0          75.0
# 2                2.0          4.0      0.0          76.0
# 3                1.0          7.0      0.0          87.0
# 4                1.0          7.0      0.0          77.0
#
#    General Education Place  History, Museum & Arts  Hotel  \
# 0                      6.0                    29.0   19.0
# 1                      4.0                    25.0   19.0
# 2                      2.0                    26.0   22.0
# 3                      6.0                    18.0   19.0
# 4                      1.0                    22.0   26.0
#
#    Indoor Entertainment  Medical-Related Place  Neighborhood  ...  \
# 0                 234.0                   19.0          22.0  ...
# 1                 211.0                   24.0          33.0  ...
# 2                 185.0                   20.0          30.0  ...
# 3                 199.0                   22.0          32.0  ...
# 4                 198.0                   17.0          26.0  ...
#
#    Place for Sports  Residence  Rest Area  Restaurant  School  Smoke Shop  \
# 0             107.0      107.0        0.0       314.0    25.0         0.0
# 1              85.0       97.0        0.0       289.0    20.0         1.0
# 2              62.0       92.0        0.0       292.0    17.0         3.0
# 3              66.0       99.0        1.0       282.0    20.0         9.0
# 4              78.0       93.0        0.0       248.0    22.0         9.0
#
#    Store, Market & Fair  Transportation  Travel-Related Place  \
# 0                  28.0           124.0                   5.0
# 1                  24.0           122.0                   4.0
# 2                  23.0           102.0                   3.0
# 3                  25.0           111.0                   1.0
# 4                  23.0           111.0                   2.0
#
#    Vehicle-Related Place
# 0                    5.0
# 1                   11.0
# 2                   12.0
# 3                   14.0
# 4                    9.0
#
# [5 rows x 22 columns]

# %%
data_mpi.head()
# Out:
#    Convention Center  Electronics   Factory  Food & Snack  \
# 0           0.046875     0.026415  0.047619      0.049044
# 1           0.015625     0.015094  0.047619      0.065395
# 2           0.031250     0.011321  0.000000      0.071970
# 3           0.015625     0.022642  0.000000      0.072089
# 4           0.015625     0.022642  0.000000      0.072848
#
#    General Education Place  History, Museum & Arts     Hotel  \
# 0                 0.032086                0.027523  0.034783
# 1                 0.021390                0.025229  0.040580
# 2                 0.010695                0.026376  0.040580
# 3                 0.021390                0.019495  0.046377
# 4                 0.005348                0.022936  0.043478
#
#    Indoor Entertainment  Medical-Related Place  Neighborhood  ...  \
# 0              0.194514               0.015794      0.061489  ...
# 1              0.191644               0.020890      0.087379  ...
# 2              0.174242               0.017992      0.071197  ...
# 3              0.181146               0.020333      0.077670  ...
# 4              0.185430               0.015137      0.064725  ...
#
#    Place for Sports  Residence  Rest Area  Restaurant    School  Smoke Shop  \
# 0          0.084788   0.085619   0.000000    0.258520  0.016337    0.000000
# 1          0.076294   0.080836   0.000000    0.260672  0.017257    0.034483
# 2          0.057765   0.084280   0.000000    0.268939  0.014617    0.034483
# 3          0.060074   0.087800   0.038462    0.257856  0.017560    0.068966
# 4          0.072848   0.087039   0.000000    0.232734  0.018921    0.034483
#
#    Store, Market & Fair  Transportation  Travel-Related Place  \
# 0              0.053763        0.096426              0.022321
# 1              0.043011        0.105359              0.017857
# 2              0.040860        0.092803              0.013393
# 3              0.049462        0.097043              0.004464
# 4              0.043011        0.099338              0.008929
#
#    Vehicle-Related Place
# 0               0.009709
# 1               0.021359
# 2               0.023301
# 3               0.027184
# 4               0.015534
#
# [5 rows x 22 columns]

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(16,8))
for colo in prevalent_colo:
    plt.plot(data_mpi[colo],label=colo)
plt.legend()
plt.show()

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(16,8))
for colo in prevalent_colo:
    plt.plot(data_colo[colo],label=colo)
plt.legend()
plt.show()

# %% [markdown]
# ### Use prevalent_colo, data_colo, data_mpi for later analysis

# %%
prevalent_colo
# Out:
# array(['Convention Center', 'Electronics', 'Factory', 'Food & Snack',
#        'General Education Place', 'History, Museum & Arts', 'Hotel',
#        'Indoor Entertainment', 'Medical-Related Place', 'Neighborhood',
#        'Office', 'Outdoor Entertainment', 'Place for Sports', 'Residence',
#        'Rest Area', 'Restaurant', 'School', 'Smoke Shop',
#        'Store, Market & Fair', 'Transportation', 'Travel-Related Place',
#        'Vehicle-Related Place'], dtype=object)

# %%
data_colo.head()
# Out:
#    Convention Center  Electronics  Factory  Food & Snack  \
# 0                3.0          7.0      1.0          61.0
# 1                1.0          4.0      1.0          75.0
# 2                2.0          4.0      0.0          76.0
# 3                1.0          7.0      0.0          87.0
# 4                1.0          7.0      0.0          77.0
#
#    General Education Place  History, Museum & Arts  Hotel  \
# 0                      6.0                    29.0   19.0
# 1                      4.0                    25.0   19.0
# 2                      2.0                    26.0   22.0
# 3                      6.0                    18.0   19.0
# 4                      1.0                    22.0   26.0
#
#    Indoor Entertainment  Medical-Related Place  Neighborhood  ...  \
# 0                 234.0                   19.0          22.0  ...
# 1                 211.0                   24.0          33.0  ...
# 2                 185.0                   20.0          30.0  ...
# 3                 199.0                   22.0          32.0  ...
# 4                 198.0                   17.0          26.0  ...
#
#    Place for Sports  Residence  Rest Area  Restaurant  School  Smoke Shop  \
# 0             107.0      107.0        0.0       314.0    25.0         0.0
# 1              85.0       97.0        0.0       289.0    20.0         1.0
# 2              62.0       92.0        0.0       292.0    17.0         3.0
# 3              66.0       99.0        1.0       282.0    20.0         9.0
# 4              78.0       93.0        0.0       248.0    22.0         9.0
#
#    Store, Market & Fair  Transportation  Travel-Related Place  \
# 0                  28.0           124.0                   5.0
# 1                  24.0           122.0                   4.0
# 2                  23.0           102.0                   3.0
# 3                  25.0           111.0                   1.0
# 4                  23.0           111.0                   2.0
#
#    Vehicle-Related Place
# 0                    5.0
# 1                   11.0
# 2                   12.0
# 3                   14.0
# 4                    9.0
#
# [5 rows x 22 columns]

# %%
guo_index = 'Transportation'
guo = np.array(data_colo[guo_index]).reshape((-1,1))
guo = guo[1:]-guo[:-1]
causes = []
for colo in prevalent_colo:
    colo = str(colo)
    if colo!=guo_index:
        yin = np.array(data_colo[colo]).reshape((-1,1))
        yin = yin[1:]-yin[:-1]
        df = np.concatenate((guo,yin),axis=1)
        lags = select_time_lags(yin)
        results = grangercausalitytests(df, maxlag=[lags])
        if (results[lags])[0]['ssr_ftest'][1]<=0.15:
            causes.append(colo)
# Out:
# Granger Causality
# number of lags (no zero) 4
# ssr based F test:         F=0.8000  , p=0.5260  , df_denom=274, df_num=4
# ssr based chi2 test:   chi2=3.3053  , p=0.5081  , df=4
# likelihood ratio test: chi2=3.2862  , p=0.5111  , df=4
# parameter F test:         F=0.8000  , p=0.5260  , df_denom=274, df_num=4
#
# Granger Causality
# number of lags (no zero) 4
# ssr based F test:         F=0.3752  , p=0.8262  , df_denom=274, df_num=4
# ssr based chi2 test:   chi2=1.5503  , p=0.8177  , df=4
# likelihood ratio test: chi2=1.5461  , p=0.8185  , df=4
# parameter F test:         F=0.3752  , p=0.8262  , df_denom=274, df_num=4
#
# Granger Causality
# number of lags (no zero) 5
# ssr based F test:         F=0.7508  , p=0.5861  , df_denom=271, df_num=5
# ssr based chi2 test:   chi2=3.9062  , p=0.5630  , df=5
# likelihood ratio test: chi2=3.8794  , p=0.5669  , df=5
# parameter F test:         F=0.7508  , p=0.5861  , df_denom=271, df_num=5
#
# Granger Causality
# number of lags (no zero) 3
# ssr based F test:         F=1.1570  , p=0.3266  , df_denom=277, df_num=3
# ssr based chi2 test:   chi2=3.5586  , p=0.3132  , df=3
# likelihood ratio test: chi2=3.5365  , p=0.3161  , df=3
# parameter F test:         F=1.1570  , p=0.3266  , df_denom=277, df_num=3
#
# Granger Causality
# number of lags (no zero) 3
# ssr based F test:         F=1.3917  , p=0.2456  , df_denom=277, df_num=3
# ssr based chi2 test:   chi2=4.2805  , p=0.2327  , df=3
# likelihood ratio test: chi2=4.2486  , p=0.2358  , df=3
# parameter F test:         F=1.3917  , p=0.2456  , df_denom=277, df_num=3
#
# Granger Causality
# number of lags (no zero) 6
# ssr based F test:         F=1.0722  , p=0.3795  , df_denom=268, df_num=6
# ssr based chi2 test:   chi2=6.7451  , p=0.3451  , df=6
# likelihood ratio test: chi2=6.6654  , p=0.3529  , df=6
# parameter F test:         F=1.0722  , p=0.3795  , df_denom=268, df_num=6
#
# Granger Causality
# number of lags (no zero) 7
# ssr based F test:         F=0.3739  , p=0.9171  , df_denom=265, df_num=7
# ssr based chi2 test:   chi2=2.7656  , p=0.9058  , df=7
# likelihood ratio test: chi2=2.7520  , p=0.9070  , df=7
# parameter F test:         F=0.3739  , p=0.9171  , df_denom=265, df_num=7
#
# Granger Causality
# number of lags (no zero) 3
# ssr based F test:         F=0.3664  , p=0.7773  , df_denom=277, df_num=3
# ssr based chi2 test:   chi2=1.1270  , p=0.7706  , df=3
# likelihood ratio test: chi2=1.1247  , p=0.7711  , df=3
# parameter F test:         F=0.3664  , p=0.7773  , df_denom=277, df_num=3
#
# Granger Causality
# number of lags (no zero) 2
# ssr based F test:         F=0.0954  , p=0.9090  , df_denom=280, df_num=2
# ssr based chi2 test:   chi2=0.1943  , p=0.9074  , df=2
# likelihood ratio test: chi2=0.1942  , p=0.9074  , df=2
# parameter F test:         F=0.0954  , p=0.9090  , df_denom=280, df_num=2
#
# Granger Causality
# number of lags (no zero) 2
# ssr based F test:         F=0.7185  , p=0.4884  , df_denom=280, df_num=2
# ssr based chi2 test:   chi2=1.4626  , p=0.4813  , df=2
# likelihood ratio test: chi2=1.4589  , p=0.4822  , df=2
# parameter F test:         F=0.7185  , p=0.4884  , df_denom=280, df_num=2
#
# Granger Causality
# number of lags (no zero) 1
# ssr based F test:         F=1.4271  , p=0.2332  , df_denom=283, df_num=1
# ssr based chi2 test:   chi2=1.4422  , p=0.2298  , df=1
# likelihood ratio test: chi2=1.4386  , p=0.2304  , df=1
# parameter F test:         F=1.4271  , p=0.2332  , df_denom=283, df_num=1
#
# Granger Causality
# number of lags (no zero) 3
# ssr based F test:         F=1.2150  , p=0.3046  , df_denom=277, df_num=3
# ssr based chi2 test:   chi2=3.7370  , p=0.2913  , df=3
# likelihood ratio test: chi2=3.7126  , p=0.2942  , df=3
# parameter F test:         F=1.2150  , p=0.3046  , df_denom=277, df_num=3
#
# Granger Causality
# number of lags (no zero) 3
# ssr based F test:         F=3.0553  , p=0.0288  , df_denom=277, df_num=3
# ssr based chi2 test:   chi2=9.3975  , p=0.0244  , df=3
# likelihood ratio test: chi2=9.2454  , p=0.0262  , df=3
# parameter F test:         F=3.0553  , p=0.0288  , df_denom=277, df_num=3
#
# Granger Causality
# number of lags (no zero) 5
# ssr based F test:         F=1.2257  , p=0.2972  , df_denom=271, df_num=5
# ssr based chi2 test:   chi2=6.3774  , p=0.2712  , df=5
# likelihood ratio test: chi2=6.3064  , p=0.2775  , df=5
# parameter F test:         F=1.2257  , p=0.2972  , df_denom=271, df_num=5
#
# Granger Causality
# number of lags (no zero) 4
# ssr based F test:         F=0.5132  , p=0.7261  , df_denom=274, df_num=4
# ssr based chi2 test:   chi2=2.1202  , p=0.7137  , df=4
# likelihood ratio test: chi2=2.1123  , p=0.7151  , df=4
# parameter F test:         F=0.5132  , p=0.7261  , df_denom=274, df_num=4
#
# Granger Causality
# number of lags (no zero) 1
# ssr based F test:         F=0.4872  , p=0.4858  , df_denom=283, df_num=1
# ssr based chi2 test:   chi2=0.4923  , p=0.4829  , df=1
# likelihood ratio test: chi2=0.4919  , p=0.4831  , df=1
# parameter F test:         F=0.4872  , p=0.4858  , df_denom=283, df_num=1
#
# Granger Causality
# number of lags (no zero) 3
# ssr based F test:         F=1.5509  , p=0.2016  , df_denom=277, df_num=3
# ssr based chi2 test:   chi2=4.7703  , p=0.1894  , df=3
# likelihood ratio test: chi2=4.7306  , p=0.1926  , df=3
# parameter F test:         F=1.5509  , p=0.2016  , df_denom=277, df_num=3
#
# Granger Causality
# number of lags (no zero) 4
# ssr based F test:         F=0.0758  , p=0.9896  , df_denom=274, df_num=4
# ssr based chi2 test:   chi2=0.3131  , p=0.9890  , df=4
# likelihood ratio test: chi2=0.3129  , p=0.9890  , df=4
# parameter F test:         F=0.0758  , p=0.9896  , df_denom=274, df_num=4
#
# Granger Causality
# number of lags (no zero) 4
# ssr based F test:         F=0.6645  , p=0.6171  , df_denom=274, df_num=4
# ssr based chi2 test:   chi2=2.7455  , p=0.6013  , df=4
# likelihood ratio test: chi2=2.7323  , p=0.6036  , df=4
# parameter F test:         F=0.6645  , p=0.6171  , df_denom=274, df_num=4
#
# Granger Causality
# number of lags (no zero) 6
# ssr based F test:         F=2.2449  , p=0.0394  , df_denom=268, df_num=6
# ssr based chi2 test:   chi2=14.1228 , p=0.0283  , df=6
# likelihood ratio test: chi2=13.7793 , p=0.0322  , df=6
# parameter F test:         F=2.2449  , p=0.0394  , df_denom=268, df_num=6
#
# Granger Causality
# number of lags (no zero) 3
# ssr based F test:         F=2.2284  , p=0.0851  , df_denom=277, df_num=3
# ssr based chi2 test:   chi2=6.8542  , p=0.0767  , df=3
# likelihood ratio test: chi2=6.7728  , p=0.0795  , df=3
# parameter F test:         F=2.2284  , p=0.0851  , df_denom=277, df_num=3

# %%
causes
# Out:
# ['Place for Sports', 'Travel-Related Place', 'Vehicle-Related Place']

# %%
dd = dict()
for guo_index in prevalent_colo:
    #guo_index = 'Transportation'
    guo = np.array(data_colo[guo_index]).reshape((-1,1))
    guo = guo[1:]-guo[:-1]
    causes = []
    for colo in prevalent_colo:
        colo = str(colo)
        if colo!=guo_index:
            yin = np.array(data_colo[colo]).reshape((-1,1))
            yin = yin[1:]-yin[:-1]
            df = np.concatenate((guo,yin),axis=1)
            lags = select_time_lags(yin)
            results = grangercausalitytests(df, maxlag=[lags])
            if (results[lags])[0]['ssr_ftest'][1]<=0.15:
                causes.append(colo)
    #print("{}, {}".format(guo_index,causes))
    dd[guo_index] = causes
# Out:
# Granger Causality
# number of lags (no zero) 4
# ssr based F test:         F=1.1578  , p=0.3298  , df_denom=274, df_num=4
# ssr based chi2 test:   chi2=4.7833  , p=0.3103  , df=4
# likelihood ratio test: chi2=4.7433  , p=0.3147  , df=4
# parameter F test:         F=1.1578  , p=0.3298  , df_denom=274, df_num=4
#
# Granger Causality
# number of lags (no zero) 5
# ssr based F test:         F=1.4969  , p=0.1910  , df_denom=271, df_num=5
# ssr based chi2 test:   chi2=7.7884  , p=0.1683  , df=5
# likelihood ratio test: chi2=7.6827  , p=0.1746  , df=5
# parameter F test:         F=1.4969  , p=0.1910  , df_denom=271, df_num=5
#
# Granger Causality
# number of lags (no zero) 3
# ssr based F test:         F=0.9983  , p=0.3941  , df_denom=277, df_num=3
# ssr based chi2 test:   chi2=3.0706  , p=0.3809  , df=3
# likelihood ratio test: chi2=3.0542  , p=0.3834  , df=3
# parameter F test:         F=0.9983  , p=0.3941  , df_denom=277, df_num=3
#
# Granger Causality
# number of lags (no zero) 3
# ssr based F test:         F=0.5038  , p=0.6800  , df_denom=277, df_num=3
# ssr based chi2 test:   chi2=1.5494  , p=0.6709  , df=3
# likelihood ratio test: chi2=1.5452  , p=0.6719  , df=3
# parameter F test:         F=0.5038  , p=0.6800  , df_denom=277, df_num=3
#
# Granger Causality
# number of lags (no zero) 6
# ssr based F test:         F=0.3478  , p=0.9108  , df_denom=268, df_num=6
# ssr based chi2 test:   chi2=2.1880  , p=0.9016  , df=6
# likelihood ratio test: chi2=2.1795  , p=0.9025  , df=6
# parameter F test:         F=0.3478  , p=0.9108  , df_denom=268, df_num=6
#
# Granger Causality
# number of lags (no zero) 7
# ssr based F test:         F=0.1428  , p=0.9947  , df_denom=265, df_num=7
# ssr based chi2 test:   chi2=1.0565  , p=0.9939  , df=7
# likelihood ratio test: chi2=1.0545  , p=0.9939  , df=7
# parameter F test:         F=0.1428  , p=0.9947  , df_denom=265, df_num=7
#
# Granger Causality
# number of lags (no zero) 3
# ssr based F test:         F=3.8162  , p=0.0105  , df_denom=277, df_num=3
# ssr based chi2 test:   chi2=11.7380 , p=0.0083  , df=3
# likelihood ratio test: chi2=11.5019 , p=0.0093  , df=3
# parameter F test:         F=3.8162  , p=0.0105  , df_denom=277, df_num=3
#
# Granger Causality
# number of lags (no zero) 2
# ssr based F test:         F=0.2530  , p=0.7766  , df_denom=280, df_num=2
# ssr based chi2 test:   chi2=0.5150  , p=0.7730  , df=2
# likelihood ratio test: chi2=0.5146  , p=0.7731  , df=2
# parameter F test:         F=0.2530  , p=0.7766  , df_denom=280, df_num=2
#
# Granger Causality
# number of lags (no zero) 2
# ssr based F test:         F=1.2011  , p=0.3024  , df_denom=280, df_num=2
# ssr based chi2 test:   chi2=2.4451  , p=0.2945  , df=2
# likelihood ratio test: chi2=2.4346  , p=0.2960  , df=2
# parameter F test:         F=1.2011  , p=0.3024  , df_denom=280, df_num=2
#
# Granger Causality
# number of lags (no zero) 1
# ssr based F test:         F=3.4966  , p=0.0625  , df_denom=283, df_num=1
# ssr based chi2 test:   chi2=3.5337  , p=0.0601  , df=1
# likelihood ratio test: chi2=3.5120  , p=0.0609  , df=1
# parameter F test:         F=3.4966  , p=0.0625  , df_denom=283, df_num=1
#
# Granger Causality
# number of lags (no zero) 3
# ssr based F test:         F=1.3226  , p=0.2673  , df_denom=277, df_num=3
# ssr based chi2 test:   chi2=4.0681  , p=0.2542  , df=3
# likelihood ratio test: chi2=4.0392  , p=0.2573  , df=3
# parameter F test:         F=1.3226  , p=0.2673  , df_denom=277, df_num=3
#
# Granger Causality
# number of lags (no zero) 3
# ssr based F test:         F=0.3866  , p=0.7627  , df_denom=277, df_num=3
# ssr based chi2 test:   chi2=1.1893  , p=0.7556  , df=3
# likelihood ratio test: chi2=1.1868  , p=0.7562  , df=3
# parameter F test:         F=0.3866  , p=0.7627  , df_denom=277, df_num=3
#
# Granger Causality
# number of lags (no zero) 5
# ssr based F test:         F=2.7683  , p=0.0186  , df_denom=271, df_num=5
# ssr based chi2 test:   chi2=14.4036 , p=0.0132  , df=5
# likelihood ratio test: chi2=14.0478 , p=0.0153  , df=5
# parameter F test:         F=2.7683  , p=0.0186  , df_denom=271, df_num=5
#
# Granger Causality
# number of lags (no zero) 4
# ssr based F test:         F=0.7694  , p=0.5459  , df_denom=274, df_num=4
# ssr based chi2 test:   chi2=3.1786  , p=0.5284  , df=4
# likelihood ratio test: chi2=3.1609  , p=0.5313  , df=4
# parameter F test:         F=0.7694  , p=0.5459  , df_denom=274, df_num=4
#
# Granger Causality
# number of lags (no zero) 1
# ssr based F test:         F=0.8488  , p=0.3577  , df_denom=283, df_num=1
# ssr based chi2 test:   chi2=0.8578  , p=0.3544  , df=1
# likelihood ratio test: chi2=0.8565  , p=0.3547  , df=1
# parameter F test:         F=0.8488  , p=0.3577  , df_denom=283, df_num=1
#
# Granger Causality
# number of lags (no zero) 3
# ssr based F test:         F=0.8007  , p=0.4944  , df_denom=277, df_num=3
# ssr based chi2 test:   chi2=2.4629  , p=0.4820  , df=3
# likelihood ratio test: chi2=2.4523  , p=0.4840  , df=3
# parameter F test:         F=0.8007  , p=0.4944  , df_denom=277, df_num=3
#
# Granger Causality
# number of lags (no zero) 4
# ssr based F test:         F=0.7399  , p=0.5655  , df_denom=274, df_num=4
# ssr based chi2 test:   chi2=3.0570  , p=0.5483  , df=4
# likelihood ratio test: chi2=3.0406  , p=0.5511  , df=4
# parameter F test:         F=0.7399  , p=0.5655  , df_denom=274, df_num=4
#
# Granger Causality
# number of lags (no zero) 4
# ssr based F test:         F=1.9244  , p=0.1066  , df_denom=274, df_num=4
# ssr based chi2 test:   chi2=7.9504  , p=0.0934  , df=4
# likelihood ratio test: chi2=7.8408  , p=0.0976  , df=4
# parameter F test:         F=1.9244  , p=0.1066  , df_denom=274, df_num=4
#
# Granger Causality
# number of lags (no zero) 2
# ssr based F test:         F=6.3881  , p=0.0019  , df_denom=280, df_num=2
# ssr based chi2 test:   chi2=13.0044 , p=0.0015  , df=2
# likelihood ratio test: chi2=12.7165 , p=0.0017  , df=2
# parameter F test:         F=6.3881  , p=0.0019  , df_denom=280, df_num=2
#
# Granger Causality
# number of lags (no zero) 6
# ssr based F test:         F=2.2130  , p=0.0422  , df_denom=268, df_num=6
# ssr based chi2 test:   chi2=13.9218 , p=0.0305  , df=6
# likelihood ratio test: chi2=13.5879 , p=0.0346  , df=6
# parameter F test:         F=2.2130  , p=0.0422  , df_denom=268, df_num=6
#
# Granger Causality
# number of lags (no zero) 3
# ssr based F test:         F=1.4213  , p=0.2368  , df_denom=277, df_num=3
# ssr based chi2 test:   chi2=4.3716  , p=0.2240  , df=3
# likelihood ratio test: chi2=4.3383  , p=0.2272  , df=3
# parameter F test:         F=1.4213  , p=0.2368  , df_denom=277, df_num=3
#
# Granger Causality
# number of lags (no zero) 4
# ssr based F test:         F=1.4485  , p=0.2182  , df_denom=274, df_num=4
# ssr based chi2 test:   chi2=5.9844  , p=0.2003  , df=4
# likelihood ratio test: chi2=5.9220  , p=0.2051  , df=4
# parameter F test:         F=1.4485  , p=0.2182  , df_denom=274, df_num=4
#
# Granger Causality
# number of lags (no zero) 5
# ssr based F test:         F=0.6364  , p=0.6721  , df_denom=271, df_num=5
# ssr based chi2 test:   chi2=3.3113  , p=0.6521  , df=5
# likelihood ratio test: chi2=3.2920  , p=0.6551  , df=5
# parameter F test:         F=0.6364  , p=0.6721  , df_denom=271, df_num=5
#
# Granger Causality
# number of lags (no zero) 3
# ssr based F test:         F=0.0580  , p=0.9816  , df_denom=277, df_num=3
# ssr based chi2 test:   chi2=0.1785  , p=0.9810  , df=3
# likelihood ratio test: chi2=0.1784  , p=0.9810  , df=3
# parameter F test:         F=0.0580  , p=0.9816  , df_denom=277, df_num=3
#
# Granger Causality
# number of lags (no zero) 3
# ssr based F test:         F=1.9873  , p=0.1161  , df_denom=277, df_num=3
# ssr based chi2 test:   chi2=6.1125  , p=0.1063  , df=3
# likelihood ratio test: chi2=6.0477  , p=0.1093  , df=3
# parameter F test:         F=1.9873  , p=0.1161  , df_denom=277, df_num=3
#
# Granger Causality
# number of lags (no zero) 6
# ssr based F test:         F=0.3628  , p=0.9020  , df_denom=268, df_num=6
# ssr based chi2 test:   chi2=2.2825  , p=0.8920  , df=6
# likelihood ratio test: chi2=2.2733  , p=0.8929  , df=6
# parameter F test:         F=0.3628  , p=0.9020  , df_denom=268, df_num=6
#
# Granger Causality
# number of lags (no zero) 7
# ssr based F test:         F=0.7235  , p=0.6522  , df_denom=265, df_num=7
# ssr based chi2 test:   chi2=5.3510  , p=0.6172  , df=7
# likelihood ratio test: chi2=5.3005  , p=0.6233  , df=7
# parameter F test:         F=0.7235  , p=0.6522  , df_denom=265, df_num=7
#
# Granger Causality
# number of lags (no zero) 3
# ssr based F test:         F=3.8278  , p=0.0103  , df_denom=277, df_num=3
# ssr based chi2 test:   chi2=11.7736 , p=0.0082  , df=3
# likelihood ratio test: chi2=11.5361 , p=0.0092  , df=3
# parameter F test:         F=3.8278  , p=0.0103  , df_denom=277, df_num=3
#
# Granger Causality
# number of lags (no zero) 2
# ssr based F test:         F=2.0886  , p=0.1258  , df_denom=280, df_num=2
# ssr based chi2 test:   chi2=4.2517  , p=0.1193  , df=2
# likelihood ratio test: chi2=4.2203  , p=0.1212  , df=2
# parameter F test:         F=2.0886  , p=0.1258  , df_denom=280, df_num=2
#
# Granger Causality
# number of lags (no zero) 2
# ssr based F test:         F=1.7653  , p=0.1730  , df_denom=280, df_num=2
# ssr based chi2 test:   chi2=3.5937  , p=0.1658  , df=2
# likelihood ratio test: chi2=3.5713  , p=0.1677  , df=2
# parameter F test:         F=1.7653  , p=0.1730  , df_denom=280, df_num=2
#
# Granger Causality
# number of lags (no zero) 1
# ssr based F test:         F=3.0512  , p=0.0818  , df_denom=283, df_num=1
# ssr based chi2 test:   chi2=3.0835  , p=0.0791  , df=1
# likelihood ratio test: chi2=3.0670  , p=0.0799  , df=1
# parameter F test:         F=3.0512  , p=0.0818  , df_denom=283, df_num=1
#
# Granger Causality
# number of lags (no zero) 3
# ssr based F test:         F=0.5920  , p=0.6207  , df_denom=277, df_num=3
# ssr based chi2 test:   chi2=1.8209  , p=0.6104  , df=3
# likelihood ratio test: chi2=1.8151  , p=0.6117  , df=3
# parameter F test:         F=0.5920  , p=0.6207  , df_denom=277, df_num=3
#
# Granger Causality
# number of lags (no zero) 3
# ssr based F test:         F=0.4769  , p=0.6986  , df_denom=277, df_num=3
# ssr based chi2 test:   chi2=1.4668  , p=0.6899  , df=3
# likelihood ratio test: chi2=1.4630  , p=0.6908  , df=3
# parameter F test:         F=0.4769  , p=0.6986  , df_denom=277, df_num=3
#
# Granger Causality
# number of lags (no zero) 5
# ssr based F test:         F=0.7647  , p=0.5760  , df_denom=271, df_num=5
# ssr based chi2 test:   chi2=3.9785  , p=0.5525  , df=5
# likelihood ratio test: chi2=3.9507  , p=0.5565  , df=5
# parameter F test:         F=0.7647  , p=0.5760  , df_denom=271, df_num=5
# Granger Causality
# number of lags (no zero) 4
# ssr based F test:         F=0.2789  , p=0.8915  , df_denom=274, df_num=4
# ssr based chi2 test:   chi2=1.1522  , p=0.8859  , df=4
# likelihood ratio test: chi2=1.1499  , p=0.8863  , df=4
# parameter F test:         F=0.2789  , p=0.8915  , df_denom=274, df_num=4
#
# Granger Causality
# number of lags (no zero) 1
# ssr based F test:         F=1.0275  , p=0.3116  , df_denom=283, df_num=1
# ssr based chi2 test:   chi2=1.0384  , p=0.3082  , df=1
# likelihood ratio test: chi2=1.0365  , p=0.3086  , df=1
# parameter F test:         F=1.0275  , p=0.3116  , df_denom=283, df_num=1
#
# Granger Causality
# number of lags (no zero) 3
# ssr based F test:         F=1.0013  , p=0.3927  , df_denom=277, df_num=3
# ssr based chi2 test:   chi2=3.0798  , p=0.3795  , df=3
# likelihood ratio test: chi2=3.0632  , p=0.3820  , df=3
# parameter F test:         F=1.0013  , p=0.3927  , df_denom=277, df_num=3
#
# Granger Causality
# number of lags (no zero) 4
# ssr based F test:         F=1.9352  , p=0.1048  , df_denom=274, df_num=4
# ssr based chi2 test:   chi2=7.9953  , p=0.0918  , df=4
# likelihood ratio test: chi2=7.8844  , p=0.0959  , df=4
# parameter F test:         F=1.9352  , p=0.1048  , df_denom=274, df_num=4
#
# Granger Causality
# number of lags (no zero) 4
# ssr based F test:         F=1.9195  , p=0.1074  , df_denom=274, df_num=4
# ssr based chi2 test:   chi2=7.9303  , p=0.0942  , df=4
# likelihood ratio test: chi2=7.8212  , p=0.0984  , df=4
# parameter F test:         F=1.9195  , p=0.1074  , df_denom=274, df_num=4
#
# Granger Causality
# number of lags (no zero) 2
# ssr based F test:         F=0.2276  , p=0.7966  , df_denom=280, df_num=2
# ssr based chi2 test:   chi2=0.4633  , p=0.7932  , df=2
# likelihood ratio test: chi2=0.4629  , p=0.7934  , df=2
# parameter F test:         F=0.2276  , p=0.7966  , df_denom=280, df_num=2
#
# Granger Causality
# number of lags (no zero) 6
# ssr based F test:         F=1.6889  , p=0.1238  , df_denom=268, df_num=6
# ssr based chi2 test:   chi2=10.6250 , p=0.1007  , df=6
# likelihood ratio test: chi2=10.4291 , p=0.1077  , df=6
# parameter F test:         F=1.6889  , p=0.1238  , df_denom=268, df_num=6
#
# Granger Causality
# number of lags (no zero) 3
# ssr based F test:         F=1.4717  , p=0.2225  , df_denom=277, df_num=3
# ssr based chi2 test:   chi2=4.5265  , p=0.2099  , df=3
# likelihood ratio test: chi2=4.4908  , p=0.2131  , df=3
# parameter F test:         F=1.4717  , p=0.2225  , df_denom=277, df_num=3
#
# Granger Causality
# number of lags (no zero) 4
# ssr based F test:         F=2.7027  , p=0.0309  , df_denom=274, df_num=4
# ssr based chi2 test:   chi2=11.1660 , p=0.0248  , df=4
# likelihood ratio test: chi2=10.9513 , p=0.0271  , df=4
# parameter F test:         F=2.7027  , p=0.0309  , df_denom=274, df_num=4
#
# Granger Causality
# number of lags (no zero) 4
# ssr based F test:         F=0.1647  , p=0.9561  , df_denom=274, df_num=4
# ssr based chi2 test:   chi2=0.6805  , p=0.9537  , df=4
# likelihood ratio test: chi2=0.6797  , p=0.9538  , df=4
# parameter F test:         F=0.1647  , p=0.9561  , df_denom=274, df_num=4
#
# Granger Causality
# number of lags (no zero) 3
# ssr based F test:         F=6.6749  , p=0.0002  , df_denom=277, df_num=3
# ssr based chi2 test:   chi2=20.5308 , p=0.0001  , df=3
# likelihood ratio test: chi2=19.8226 , p=0.0002  , df=3
# parameter F test:         F=6.6749  , p=0.0002  , df_denom=277, df_num=3
#
# Granger Causality
# number of lags (no zero) 3
# ssr based F test:         F=0.3755  , p=0.7707  , df_denom=277, df_num=3
# ssr based chi2 test:   chi2=1.1551  , p=0.7638  , df=3
# likelihood ratio test: chi2=1.1528  , p=0.7644  , df=3
# parameter F test:         F=0.3755  , p=0.7707  , df_denom=277, df_num=3
#
# Granger Causality
# number of lags (no zero) 6
# ssr based F test:         F=1.4611  , p=0.1918  , df_denom=268, df_num=6
# ssr based chi2 test:   chi2=9.1917  , p=0.1631  , df=6
# likelihood ratio test: chi2=9.0446  , p=0.1711  , df=6
# parameter F test:         F=1.4611  , p=0.1918  , df_denom=268, df_num=6
#
# Granger Causality
# number of lags (no zero) 7
# ssr based F test:         F=0.7476  , p=0.6318  , df_denom=265, df_num=7
# ssr based chi2 test:   chi2=5.5297  , p=0.5956  , df=7
# likelihood ratio test: chi2=5.4758  , p=0.6021  , df=7
# parameter F test:         F=0.7476  , p=0.6318  , df_denom=265, df_num=7
#
# Granger Causality
# number of lags (no zero) 3
# ssr based F test:         F=0.4079  , p=0.7475  , df_denom=277, df_num=3
# ssr based chi2 test:   chi2=1.2545  , p=0.7400  , df=3
# likelihood ratio test: chi2=1.2517  , p=0.7406  , df=3
# parameter F test:         F=0.4079  , p=0.7475  , df_denom=277, df_num=3
#
# Granger Causality
# number of lags (no zero) 2
# ssr based F test:         F=1.6496  , p=0.1940  , df_denom=280, df_num=2
# ssr based chi2 test:   chi2=3.3581  , p=0.1866  , df=2
# likelihood ratio test: chi2=3.3385  , p=0.1884  , df=2
# parameter F test:         F=1.6496  , p=0.1940  , df_denom=280, df_num=2
#
# Granger Causality
# number of lags (no zero) 2
# ssr based F test:         F=0.7542  , p=0.4713  , df_denom=280, df_num=2
# ssr based chi2 test:   chi2=1.5353  , p=0.4641  , df=2
# likelihood ratio test: chi2=1.5312  , p=0.4650  , df=2
# parameter F test:         F=0.7542  , p=0.4713  , df_denom=280, df_num=2
#
# Granger Causality
# number of lags (no zero) 1
# ssr based F test:         F=0.6603  , p=0.4171  , df_denom=283, df_num=1
# ssr based chi2 test:   chi2=0.6673  , p=0.4140  , df=1
# likelihood ratio test: chi2=0.6665  , p=0.4143  , df=1
# parameter F test:         F=0.6603  , p=0.4171  , df_denom=283, df_num=1
#
# Granger Causality
# number of lags (no zero) 3
# ssr based F test:         F=1.5123  , p=0.2116  , df_denom=277, df_num=3
# ssr based chi2 test:   chi2=4.6514  , p=0.1992  , df=3
# likelihood ratio test: chi2=4.6137  , p=0.2024  , df=3
# parameter F test:         F=1.5123  , p=0.2116  , df_denom=277, df_num=3
#
# Granger Causality
# number of lags (no zero) 3
# ssr based F test:         F=0.3524  , p=0.7874  , df_denom=277, df_num=3
# ssr based chi2 test:   chi2=1.0839  , p=0.7810  , df=3
# likelihood ratio test: chi2=1.0818  , p=0.7815  , df=3
# parameter F test:         F=0.3524  , p=0.7874  , df_denom=277, df_num=3
#
# Granger Causality
# number of lags (no zero) 5
# ssr based F test:         F=1.6749  , p=0.1408  , df_denom=271, df_num=5
# ssr based chi2 test:   chi2=8.7146  , p=0.1210  , df=5
# likelihood ratio test: chi2=8.5826  , p=0.1269  , df=5
# parameter F test:         F=1.6749  , p=0.1408  , df_denom=271, df_num=5
#
# Granger Causality
# number of lags (no zero) 4
# ssr based F test:         F=1.0857  , p=0.3639  , df_denom=274, df_num=4
# ssr based chi2 test:   chi2=4.4853  , p=0.3443  , df=4
# likelihood ratio test: chi2=4.4502  , p=0.3485  , df=4
# parameter F test:         F=1.0857  , p=0.3639  , df_denom=274, df_num=4
#
# Granger Causality
# number of lags (no zero) 1
# ssr based F test:         F=1.4327  , p=0.2323  , df_denom=283, df_num=1
# ssr based chi2 test:   chi2=1.4479  , p=0.2289  , df=1
# likelihood ratio test: chi2=1.4443  , p=0.2295  , df=1
# parameter F test:         F=1.4327  , p=0.2323  , df_denom=283, df_num=1
#
# Granger Causality
# number of lags (no zero) 3
# ssr based F test:         F=5.2444  , p=0.0016  , df_denom=277, df_num=3
# ssr based chi2 test:   chi2=16.1307 , p=0.0011  , df=3
# likelihood ratio test: chi2=15.6893 , p=0.0013  , df=3
# parameter F test:         F=5.2444  , p=0.0016  , df_denom=277, df_num=3
#
# Granger Causality
# number of lags (no zero) 4
# ssr based F test:         F=0.5014  , p=0.7348  , df_denom=274, df_num=4
# ssr based chi2 test:   chi2=2.0713  , p=0.7226  , df=4
# likelihood ratio test: chi2=2.0638  , p=0.7240  , df=4
# parameter F test:         F=0.5014  , p=0.7348  , df_denom=274, df_num=4
#
# Granger Causality
# number of lags (no zero) 4
# ssr based F test:         F=0.4202  , p=0.7940  , df_denom=274, df_num=4
# ssr based chi2 test:   chi2=1.7359  , p=0.7842  , df=4
# likelihood ratio test: chi2=1.7306  , p=0.7852  , df=4
# parameter F test:         F=0.4202  , p=0.7940  , df_denom=274, df_num=4
#
# Granger Causality
# number of lags (no zero) 2
# ssr based F test:         F=2.5846  , p=0.0772  , df_denom=280, df_num=2
# ssr based chi2 test:   chi2=5.2615  , p=0.0720  , df=2
# likelihood ratio test: chi2=5.2135  , p=0.0738  , df=2
# parameter F test:         F=2.5846  , p=0.0772  , df_denom=280, df_num=2
#
# Granger Causality
# number of lags (no zero) 6
# ssr based F test:         F=8.7147  , p=0.0000  , df_denom=268, df_num=6
# ssr based chi2 test:   chi2=54.8243 , p=0.0000  , df=6
# likelihood ratio test: chi2=50.0836 , p=0.0000  , df=6
# parameter F test:         F=8.7147  , p=0.0000  , df_denom=268, df_num=6
#
# Granger Causality
# number of lags (no zero) 3
# ssr based F test:         F=2.0648  , p=0.1051  , df_denom=277, df_num=3
# ssr based chi2 test:   chi2=6.3511  , p=0.0957  , df=3
# likelihood ratio test: chi2=6.2811  , p=0.0987  , df=3
# parameter F test:         F=2.0648  , p=0.1051  , df_denom=277, df_num=3
#
# Granger Causality
# number of lags (no zero) 4
# ssr based F test:         F=1.8300  , p=0.1232  , df_denom=274, df_num=4
# ssr based chi2 test:   chi2=7.5606  , p=0.1091  , df=4
# likelihood ratio test: chi2=7.4613  , p=0.1134  , df=4
# parameter F test:         F=1.8300  , p=0.1232  , df_denom=274, df_num=4
#
# Granger Causality
# number of lags (no zero) 4
# ssr based F test:         F=1.2525  , p=0.2891  , df_denom=274, df_num=4
# ssr based chi2 test:   chi2=5.1746  , p=0.2698  , df=4
# likelihood ratio test: chi2=5.1278  , p=0.2744  , df=4
# parameter F test:         F=1.2525  , p=0.2891  , df_denom=274, df_num=4
#
# Granger Causality
# number of lags (no zero) 5
# ssr based F test:         F=1.2467  , p=0.2876  , df_denom=271, df_num=5
# ssr based chi2 test:   chi2=6.4863  , p=0.2617  , df=5
# likelihood ratio test: chi2=6.4128  , p=0.2681  , df=5
# parameter F test:         F=1.2467  , p=0.2876  , df_denom=271, df_num=5
#
# Granger Causality
# number of lags (no zero) 3
# ssr based F test:         F=1.0317  , p=0.3789  , df_denom=277, df_num=3
# ssr based chi2 test:   chi2=3.1734  , p=0.3656  , df=3
# likelihood ratio test: chi2=3.1558  , p=0.3682  , df=3
# parameter F test:         F=1.0317  , p=0.3789  , df_denom=277, df_num=3
#
# Granger Causality
# number of lags (no zero) 6
# ssr based F test:         F=5.3728  , p=0.0000  , df_denom=268, df_num=6
# ssr based chi2 test:   chi2=33.8005 , p=0.0000  , df=6
# likelihood ratio test: chi2=31.9172 , p=0.0000  , df=6
# parameter F test:         F=5.3728  , p=0.0000  , df_denom=268, df_num=6
#
# Granger Causality
# number of lags (no zero) 7
# ssr based F test:         F=0.3081  , p=0.9499  , df_denom=265, df_num=7
# ssr based chi2 test:   chi2=2.2789  , p=0.9428  , df=7
# likelihood ratio test: chi2=2.2696  , p=0.9434  , df=7
# parameter F test:         F=0.3081  , p=0.9499  , df_denom=265, df_num=7
#
# Granger Causality
# number of lags (no zero) 3
# ssr based F test:         F=0.8313  , p=0.4776  , df_denom=277, df_num=3
# ssr based chi2 test:   chi2=2.5570  , p=0.4651  , df=3
# likelihood ratio test: chi2=2.5455  , p=0.4671  , df=3
# parameter F test:         F=0.8313  , p=0.4776  , df_denom=277, df_num=3
#
# Granger Causality
# number of lags (no zero) 2
# ssr based F test:         F=0.4284  , p=0.6520  , df_denom=280, df_num=2
# ssr based chi2 test:   chi2=0.8721  , p=0.6466  , df=2
# likelihood ratio test: chi2=0.8708  , p=0.6470  , df=2
# parameter F test:         F=0.4284  , p=0.6520  , df_denom=280, df_num=2
#
# Granger Causality
# number of lags (no zero) 2
# ssr based F test:         F=0.2901  , p=0.7484  , df_denom=280, df_num=2
# ssr based chi2 test:   chi2=0.5906  , p=0.7443  , df=2
# likelihood ratio test: chi2=0.5900  , p=0.7445  , df=2
# parameter F test:         F=0.2901  , p=0.7484  , df_denom=280, df_num=2
#
# Granger Causality
# number of lags (no zero) 1
# ssr based F test:         F=0.5837  , p=0.4455  , df_denom=283, df_num=1
# ssr based chi2 test:   chi2=0.5899  , p=0.4425  , df=1
# likelihood ratio test: chi2=0.5893  , p=0.4427  , df=1
# parameter F test:         F=0.5837  , p=0.4455  , df_denom=283, df_num=1
#
# Granger Causality
# number of lags (no zero) 3
# ssr based F test:         F=4.1143  , p=0.0071  , df_denom=277, df_num=3
# ssr based chi2 test:   chi2=12.6547 , p=0.0054  , df=3
# likelihood ratio test: chi2=12.3809 , p=0.0062  , df=3
# parameter F test:         F=4.1143  , p=0.0071  , df_denom=277, df_num=3
#
# Granger Causality
# number of lags (no zero) 3
# ssr based F test:         F=0.2685  , p=0.8481  , df_denom=277, df_num=3
# ssr based chi2 test:   chi2=0.8259  , p=0.8433  , df=3
# likelihood ratio test: chi2=0.8247  , p=0.8435  , df=3
# parameter F test:         F=0.2685  , p=0.8481  , df_denom=277, df_num=3
#
# Granger Causality
# number of lags (no zero) 5
# ssr based F test:         F=1.1279  , p=0.3458  , df_denom=271, df_num=5
# ssr based chi2 test:   chi2=5.8682  , p=0.3193  , df=5
# likelihood ratio test: chi2=5.8080  , p=0.3254  , df=5
# parameter F test:         F=1.1279  , p=0.3458  , df_denom=271, df_num=5
#
# Granger Causality
# number of lags (no zero) 4
# ssr based F test:         F=1.5706  , p=0.1823  , df_denom=274, df_num=4
# ssr based chi2 test:   chi2=6.4888  , p=0.1655  , df=4
# likelihood ratio test: chi2=6.4155  , p=0.1702  , df=4
# parameter F test:         F=1.5706  , p=0.1823  , df_denom=274, df_num=4
#
# Granger Causality
# number of lags (no zero) 1
# ssr based F test:         F=3.7955  , p=0.0524  , df_denom=283, df_num=1
# ssr based chi2 test:   chi2=3.8358  , p=0.0502  , df=1
# likelihood ratio test: chi2=3.8103  , p=0.0509  , df=1
# parameter F test:         F=3.7955  , p=0.0524  , df_denom=283, df_num=1
#
# Granger Causality
# number of lags (no zero) 3
# ssr based F test:         F=2.7411  , p=0.0436  , df_denom=277, df_num=3
# ssr based chi2 test:   chi2=8.4312  , p=0.0379  , df=3
# likelihood ratio test: chi2=8.3085  , p=0.0400  , df=3
# parameter F test:         F=2.7411  , p=0.0436  , df_denom=277, df_num=3
#
# Granger Causality
# number of lags (no zero) 4
# ssr based F test:         F=0.5106  , p=0.7280  , df_denom=274, df_num=4
# ssr based chi2 test:   chi2=2.1095  , p=0.7156  , df=4
# likelihood ratio test: chi2=2.1016  , p=0.7171  , df=4
# parameter F test:         F=0.5106  , p=0.7280  , df_denom=274, df_num=4
#
# Granger Causality
# number of lags (no zero) 4
# ssr based F test:         F=3.9309  , p=0.0040  , df_denom=274, df_num=4
# ssr based chi2 test:   chi2=16.2399 , p=0.0027  , df=4
# likelihood ratio test: chi2=15.7910 , p=0.0033  , df=4
# parameter F test:         F=3.9309  , p=0.0040  , df_denom=274, df_num=4
# Granger Causality
# number of lags (no zero) 2
# ssr based F test:         F=3.6108  , p=0.0283  , df_denom=280, df_num=2
# ssr based chi2 test:   chi2=7.3507  , p=0.0253  , df=2
# likelihood ratio test: chi2=7.2575  , p=0.0265  , df=2
# parameter F test:         F=3.6108  , p=0.0283  , df_denom=280, df_num=2
#
# Granger Causality
# number of lags (no zero) 6
# ssr based F test:         F=2.2587  , p=0.0382  , df_denom=268, df_num=6
# ssr based chi2 test:   chi2=14.2096 , p=0.0274  , df=6
# likelihood ratio test: chi2=13.8620 , p=0.0312  , df=6
# parameter F test:         F=2.2587  , p=0.0382  , df_denom=268, df_num=6
#
# Granger Causality
# number of lags (no zero) 3
# ssr based F test:         F=0.3303  , p=0.8034  , df_denom=277, df_num=3
# ssr based chi2 test:   chi2=1.0160  , p=0.7974  , df=3
# likelihood ratio test: chi2=1.0142  , p=0.7978  , df=3
# parameter F test:         F=0.3303  , p=0.8034  , df_denom=277, df_num=3
#
# Granger Causality
# number of lags (no zero) 4
# ssr based F test:         F=0.7605  , p=0.5518  , df_denom=274, df_num=4
# ssr based chi2 test:   chi2=3.1420  , p=0.5343  , df=4
# likelihood ratio test: chi2=3.1247  , p=0.5372  , df=4
# parameter F test:         F=0.7605  , p=0.5518  , df_denom=274, df_num=4
#
# Granger Causality
# number of lags (no zero) 4
# ssr based F test:         F=1.4123  , p=0.2300  , df_denom=274, df_num=4
# ssr based chi2 test:   chi2=5.8348  , p=0.2118  , df=4
# likelihood ratio test: chi2=5.7755  , p=0.2166  , df=4
# parameter F test:         F=1.4123  , p=0.2300  , df_denom=274, df_num=4
#
# Granger Causality
# number of lags (no zero) 5
# ssr based F test:         F=4.1586  , p=0.0012  , df_denom=271, df_num=5
# ssr based chi2 test:   chi2=21.6367 , p=0.0006  , df=5
# likelihood ratio test: chi2=20.8468 , p=0.0009  , df=5
# parameter F test:         F=4.1586  , p=0.0012  , df_denom=271, df_num=5
#
# Granger Causality
# number of lags (no zero) 3
# ssr based F test:         F=0.5514  , p=0.6476  , df_denom=277, df_num=3
# ssr based chi2 test:   chi2=1.6959  , p=0.6378  , df=3
# likelihood ratio test: chi2=1.6909  , p=0.6390  , df=3
# parameter F test:         F=0.5514  , p=0.6476  , df_denom=277, df_num=3
#
# Granger Causality
# number of lags (no zero) 6
# ssr based F test:         F=1.1510  , p=0.3331  , df_denom=268, df_num=6
# ssr based chi2 test:   chi2=7.2407  , p=0.2992  , df=6
# likelihood ratio test: chi2=7.1490  , p=0.3073  , df=6
# parameter F test:         F=1.1510  , p=0.3331  , df_denom=268, df_num=6
#
# Granger Causality
# number of lags (no zero) 7
# ssr based F test:         F=1.9240  , p=0.0660  , df_denom=265, df_num=7
# ssr based chi2 test:   chi2=14.2303 , p=0.0472  , df=7
# likelihood ratio test: chi2=13.8805 , p=0.0533  , df=7
# parameter F test:         F=1.9240  , p=0.0660  , df_denom=265, df_num=7
#
# Granger Causality
# number of lags (no zero) 3
# ssr based F test:         F=3.0720  , p=0.0282  , df_denom=277, df_num=3
# ssr based chi2 test:   chi2=9.4490  , p=0.0239  , df=3
# likelihood ratio test: chi2=9.2953  , p=0.0256  , df=3
# parameter F test:         F=3.0720  , p=0.0282  , df_denom=277, df_num=3
#
# Granger Causality
# number of lags (no zero) 2
# ssr based F test:         F=5.3748  , p=0.0051  , df_denom=280, df_num=2
# ssr based chi2 test:   chi2=10.9415 , p=0.0042  , df=2
# likelihood ratio test: chi2=10.7367 , p=0.0047  , df=2
# parameter F test:         F=5.3748  , p=0.0051  , df_denom=280, df_num=2
#
# Granger Causality
# number of lags (no zero) 2
# ssr based F test:         F=1.6985  , p=0.1848  , df_denom=280, df_num=2
# ssr based chi2 test:   chi2=3.4576  , p=0.1775  , df=2
# likelihood ratio test: chi2=3.4368  , p=0.1794  , df=2
# parameter F test:         F=1.6985  , p=0.1848  , df_denom=280, df_num=2
#
# Granger Causality
# number of lags (no zero) 1
# ssr based F test:         F=0.3082  , p=0.5792  , df_denom=283, df_num=1
# ssr based chi2 test:   chi2=0.3115  , p=0.5768  , df=1
# likelihood ratio test: chi2=0.3113  , p=0.5769  , df=1
# parameter F test:         F=0.3082  , p=0.5792  , df_denom=283, df_num=1
#
# Granger Causality
# number of lags (no zero) 3
# ssr based F test:         F=0.4666  , p=0.7058  , df_denom=277, df_num=3
# ssr based chi2 test:   chi2=1.4352  , p=0.6973  , df=3
# likelihood ratio test: chi2=1.4316  , p=0.6981  , df=3
# parameter F test:         F=0.4666  , p=0.7058  , df_denom=277, df_num=3
#
# Granger Causality
# number of lags (no zero) 3
# ssr based F test:         F=1.7752  , p=0.1521  , df_denom=277, df_num=3
# ssr based chi2 test:   chi2=5.4602  , p=0.1410  , df=3
# likelihood ratio test: chi2=5.4083  , p=0.1442  , df=3
# parameter F test:         F=1.7752  , p=0.1521  , df_denom=277, df_num=3
#
# Granger Causality
# number of lags (no zero) 5
# ssr based F test:         F=0.7362  , p=0.5969  , df_denom=271, df_num=5
# ssr based chi2 test:   chi2=3.8304  , p=0.5741  , df=5
# likelihood ratio test: chi2=3.8047  , p=0.5779  , df=5
# parameter F test:         F=0.7362  , p=0.5969  , df_denom=271, df_num=5
#
# Granger Causality
# number of lags (no zero) 4
# ssr based F test:         F=0.0953  , p=0.9839  , df_denom=274, df_num=4
# ssr based chi2 test:   chi2=0.3937  , p=0.9830  , df=4
# likelihood ratio test: chi2=0.3934  , p=0.9830  , df=4
# parameter F test:         F=0.0953  , p=0.9839  , df_denom=274, df_num=4
#
# Granger Causality
# number of lags (no zero) 1
# ssr based F test:         F=0.3534  , p=0.5526  , df_denom=283, df_num=1
# ssr based chi2 test:   chi2=0.3572  , p=0.5501  , df=1
# likelihood ratio test: chi2=0.3570  , p=0.5502  , df=1
# parameter F test:         F=0.3534  , p=0.5526  , df_denom=283, df_num=1
#
# Granger Causality
# number of lags (no zero) 3
# ssr based F test:         F=3.7072  , p=0.0121  , df_denom=277, df_num=3
# ssr based chi2 test:   chi2=11.4028 , p=0.0097  , df=3
# likelihood ratio test: chi2=11.1798 , p=0.0108  , df=3
# parameter F test:         F=3.7072  , p=0.0121  , df_denom=277, df_num=3
#
# Granger Causality
# number of lags (no zero) 4
# ssr based F test:         F=1.8137  , p=0.1264  , df_denom=274, df_num=4
# ssr based chi2 test:   chi2=7.4932  , p=0.1120  , df=4
# likelihood ratio test: chi2=7.3958  , p=0.1164  , df=4
# parameter F test:         F=1.8137  , p=0.1264  , df_denom=274, df_num=4
#
# Granger Causality
# number of lags (no zero) 4
# ssr based F test:         F=0.8692  , p=0.4828  , df_denom=274, df_num=4
# ssr based chi2 test:   chi2=3.5911  , p=0.4642  , df=4
# likelihood ratio test: chi2=3.5685  , p=0.4675  , df=4
# parameter F test:         F=0.8692  , p=0.4828  , df_denom=274, df_num=4
#
# Granger Causality
# number of lags (no zero) 2
# ssr based F test:         F=1.2853  , p=0.2782  , df_denom=280, df_num=2
# ssr based chi2 test:   chi2=2.6166  , p=0.2703  , df=2
# likelihood ratio test: chi2=2.6046  , p=0.2719  , df=2
# parameter F test:         F=1.2853  , p=0.2782  , df_denom=280, df_num=2
#
# Granger Causality
# number of lags (no zero) 6
# ssr based F test:         F=4.3066  , p=0.0004  , df_denom=268, df_num=6
# ssr based chi2 test:   chi2=27.0928 , p=0.0001  , df=6
# likelihood ratio test: chi2=25.8650 , p=0.0002  , df=6
# parameter F test:         F=4.3066  , p=0.0004  , df_denom=268, df_num=6
#
# Granger Causality
# number of lags (no zero) 3
# ssr based F test:         F=0.4146  , p=0.7427  , df_denom=277, df_num=3
# ssr based chi2 test:   chi2=1.2752  , p=0.7350  , df=3
# likelihood ratio test: chi2=1.2724  , p=0.7357  , df=3
# parameter F test:         F=0.4146  , p=0.7427  , df_denom=277, df_num=3
#
# Granger Causality
# number of lags (no zero) 4
# ssr based F test:         F=1.9709  , p=0.0992  , df_denom=274, df_num=4
# ssr based chi2 test:   chi2=8.1424  , p=0.0865  , df=4
# likelihood ratio test: chi2=8.0274  , p=0.0906  , df=4
# parameter F test:         F=1.9709  , p=0.0992  , df_denom=274, df_num=4
#
# Granger Causality
# number of lags (no zero) 4
# ssr based F test:         F=0.6214  , p=0.6476  , df_denom=274, df_num=4
# ssr based chi2 test:   chi2=2.5671  , p=0.6327  , df=4
# likelihood ratio test: chi2=2.5556  , p=0.6347  , df=4
# parameter F test:         F=0.6214  , p=0.6476  , df_denom=274, df_num=4
#
# Granger Causality
# number of lags (no zero) 5
# ssr based F test:         F=1.6464  , p=0.1479  , df_denom=271, df_num=5
# ssr based chi2 test:   chi2=8.5660  , p=0.1277  , df=5
# likelihood ratio test: chi2=8.4385  , p=0.1337  , df=5
# parameter F test:         F=1.6464  , p=0.1479  , df_denom=271, df_num=5
#
# Granger Causality
# number of lags (no zero) 3
# ssr based F test:         F=1.2452  , p=0.2936  , df_denom=277, df_num=3
# ssr based chi2 test:   chi2=3.8300  , p=0.2804  , df=3
# likelihood ratio test: chi2=3.8044  , p=0.2834  , df=3
# parameter F test:         F=1.2452  , p=0.2936  , df_denom=277, df_num=3
#
# Granger Causality
# number of lags (no zero) 3
# ssr based F test:         F=1.6892  , p=0.1696  , df_denom=277, df_num=3
# ssr based chi2 test:   chi2=5.1956  , p=0.1580  , df=3
# likelihood ratio test: chi2=5.1487  , p=0.1612  , df=3
# parameter F test:         F=1.6892  , p=0.1696  , df_denom=277, df_num=3
#
# Granger Causality
# number of lags (no zero) 7
# ssr based F test:         F=0.3168  , p=0.9461  , df_denom=265, df_num=7
# ssr based chi2 test:   chi2=2.3433  , p=0.9384  , df=7
# likelihood ratio test: chi2=2.3335  , p=0.9391  , df=7
# parameter F test:         F=0.3168  , p=0.9461  , df_denom=265, df_num=7
#
# Granger Causality
# number of lags (no zero) 3
# ssr based F test:         F=0.9847  , p=0.4004  , df_denom=277, df_num=3
# ssr based chi2 test:   chi2=3.0288  , p=0.3872  , df=3
# likelihood ratio test: chi2=3.0128  , p=0.3897  , df=3
# parameter F test:         F=0.9847  , p=0.4004  , df_denom=277, df_num=3
#
# Granger Causality
# number of lags (no zero) 2
# ssr based F test:         F=1.2189  , p=0.2971  , df_denom=280, df_num=2
# ssr based chi2 test:   chi2=2.4814  , p=0.2892  , df=2
# likelihood ratio test: chi2=2.4706  , p=0.2907  , df=2
# parameter F test:         F=1.2189  , p=0.2971  , df_denom=280, df_num=2
#
# Granger Causality
# number of lags (no zero) 2
# ssr based F test:         F=1.6967  , p=0.1852  , df_denom=280, df_num=2
# ssr based chi2 test:   chi2=3.4540  , p=0.1778  , df=2
# likelihood ratio test: chi2=3.4333  , p=0.1797  , df=2
# parameter F test:         F=1.6967  , p=0.1852  , df_denom=280, df_num=2
#
# Granger Causality
# number of lags (no zero) 1
# ssr based F test:         F=1.8488  , p=0.1750  , df_denom=283, df_num=1
# ssr based chi2 test:   chi2=1.8684  , p=0.1717  , df=1
# likelihood ratio test: chi2=1.8623  , p=0.1724  , df=1
# parameter F test:         F=1.8488  , p=0.1750  , df_denom=283, df_num=1
#
# Granger Causality
# number of lags (no zero) 3
# ssr based F test:         F=1.0022  , p=0.3923  , df_denom=277, df_num=3
# ssr based chi2 test:   chi2=3.0827  , p=0.3790  , df=3
# likelihood ratio test: chi2=3.0661  , p=0.3815  , df=3
# parameter F test:         F=1.0022  , p=0.3923  , df_denom=277, df_num=3
#
# Granger Causality
# number of lags (no zero) 3
# ssr based F test:         F=0.5108  , p=0.6752  , df_denom=277, df_num=3
# ssr based chi2 test:   chi2=1.5710  , p=0.6660  , df=3
# likelihood ratio test: chi2=1.5667  , p=0.6670  , df=3
# parameter F test:         F=0.5108  , p=0.6752  , df_denom=277, df_num=3
#
# Granger Causality
# number of lags (no zero) 5
# ssr based F test:         F=1.9124  , p=0.0924  , df_denom=271, df_num=5
# ssr based chi2 test:   chi2=9.9500  , p=0.0767  , df=5
# likelihood ratio test: chi2=9.7785  , p=0.0818  , df=5
# parameter F test:         F=1.9124  , p=0.0924  , df_denom=271, df_num=5
#
# Granger Causality
# number of lags (no zero) 4
# ssr based F test:         F=0.3561  , p=0.8397  , df_denom=274, df_num=4
# ssr based chi2 test:   chi2=1.4710  , p=0.8318  , df=4
# likelihood ratio test: chi2=1.4672  , p=0.8324  , df=4
# parameter F test:         F=0.3561  , p=0.8397  , df_denom=274, df_num=4
#
# Granger Causality
# number of lags (no zero) 1
# ssr based F test:         F=0.6660  , p=0.4151  , df_denom=283, df_num=1
# ssr based chi2 test:   chi2=0.6731  , p=0.4120  , df=1
# likelihood ratio test: chi2=0.6723  , p=0.4123  , df=1
# parameter F test:         F=0.6660  , p=0.4151  , df_denom=283, df_num=1
#
# Granger Causality
# number of lags (no zero) 3
# ssr based F test:         F=2.5312  , p=0.0574  , df_denom=277, df_num=3
# ssr based chi2 test:   chi2=7.7856  , p=0.0507  , df=3
# likelihood ratio test: chi2=7.6808  , p=0.0531  , df=3
# parameter F test:         F=2.5312  , p=0.0574  , df_denom=277, df_num=3
#
# Granger Causality
# number of lags (no zero) 4
# ssr based F test:         F=0.5995  , p=0.6633  , df_denom=274, df_num=4
# ssr based chi2 test:   chi2=2.4766  , p=0.6488  , df=4
# likelihood ratio test: chi2=2.4659  , p=0.6508  , df=4
# parameter F test:         F=0.5995  , p=0.6633  , df_denom=274, df_num=4
#
# Granger Causality
# number of lags (no zero) 4
# ssr based F test:         F=0.6171  , p=0.6507  , df_denom=274, df_num=4
# ssr based chi2 test:   chi2=2.5495  , p=0.6358  , df=4
# likelihood ratio test: chi2=2.5381  , p=0.6378  , df=4
# parameter F test:         F=0.6171  , p=0.6507  , df_denom=274, df_num=4
#
# Granger Causality
# number of lags (no zero) 2
# ssr based F test:         F=0.7878  , p=0.4558  , df_denom=280, df_num=2
# ssr based chi2 test:   chi2=1.6038  , p=0.4485  , df=2
# likelihood ratio test: chi2=1.5993  , p=0.4495  , df=2
# parameter F test:         F=0.7878  , p=0.4558  , df_denom=280, df_num=2
#
# Granger Causality
# number of lags (no zero) 6
# ssr based F test:         F=1.5229  , p=0.1707  , df_denom=268, df_num=6
# ssr based chi2 test:   chi2=9.5803  , p=0.1435  , df=6
# likelihood ratio test: chi2=9.4207  , p=0.1513  , df=6
# parameter F test:         F=1.5229  , p=0.1707  , df_denom=268, df_num=6
#
# Granger Causality
# number of lags (no zero) 3
# ssr based F test:         F=0.5248  , p=0.6656  , df_denom=277, df_num=3
# ssr based chi2 test:   chi2=1.6142  , p=0.6562  , df=3
# likelihood ratio test: chi2=1.6096  , p=0.6572  , df=3
# parameter F test:         F=0.5248  , p=0.6656  , df_denom=277, df_num=3
#
# Granger Causality
# number of lags (no zero) 4
# ssr based F test:         F=1.5795  , p=0.1800  , df_denom=274, df_num=4
# ssr based chi2 test:   chi2=6.5253  , p=0.1632  , df=4
# likelihood ratio test: chi2=6.4512  , p=0.1679  , df=4
# parameter F test:         F=1.5795  , p=0.1800  , df_denom=274, df_num=4
# Granger Causality
# number of lags (no zero) 4
# ssr based F test:         F=0.3894  , p=0.8162  , df_denom=274, df_num=4
# ssr based chi2 test:   chi2=1.6086  , p=0.8072  , df=4
# likelihood ratio test: chi2=1.6041  , p=0.8081  , df=4
# parameter F test:         F=0.3894  , p=0.8162  , df_denom=274, df_num=4
#
# Granger Causality
# number of lags (no zero) 5
# ssr based F test:         F=1.9556  , p=0.0855  , df_denom=271, df_num=5
# ssr based chi2 test:   chi2=10.1750 , p=0.0704  , df=5
# likelihood ratio test: chi2=9.9958  , p=0.0754  , df=5
# parameter F test:         F=1.9556  , p=0.0855  , df_denom=271, df_num=5
#
# Granger Causality
# number of lags (no zero) 3
# ssr based F test:         F=0.3948  , p=0.7568  , df_denom=277, df_num=3
# ssr based chi2 test:   chi2=1.2144  , p=0.7495  , df=3
# likelihood ratio test: chi2=1.2118  , p=0.7502  , df=3
# parameter F test:         F=0.3948  , p=0.7568  , df_denom=277, df_num=3
#
# Granger Causality
# number of lags (no zero) 3
# ssr based F test:         F=0.8670  , p=0.4586  , df_denom=277, df_num=3
# ssr based chi2 test:   chi2=2.6666  , p=0.4459  , df=3
# likelihood ratio test: chi2=2.6542  , p=0.4481  , df=3
# parameter F test:         F=0.8670  , p=0.4586  , df_denom=277, df_num=3
#
# Granger Causality
# number of lags (no zero) 6
# ssr based F test:         F=0.4661  , p=0.8332  , df_denom=268, df_num=6
# ssr based chi2 test:   chi2=2.9323  , p=0.8173  , df=6
# likelihood ratio test: chi2=2.9171  , p=0.8192  , df=6
# parameter F test:         F=0.4661  , p=0.8332  , df_denom=268, df_num=6
#
# Granger Causality
# number of lags (no zero) 3
# ssr based F test:         F=0.2377  , p=0.8700  , df_denom=277, df_num=3
# ssr based chi2 test:   chi2=0.7312  , p=0.8659  , df=3
# likelihood ratio test: chi2=0.7302  , p=0.8661  , df=3
# parameter F test:         F=0.2377  , p=0.8700  , df_denom=277, df_num=3
#
# Granger Causality
# number of lags (no zero) 2
# ssr based F test:         F=0.0002  , p=0.9998  , df_denom=280, df_num=2
# ssr based chi2 test:   chi2=0.0005  , p=0.9997  , df=2
# likelihood ratio test: chi2=0.0005  , p=0.9997  , df=2
# parameter F test:         F=0.0002  , p=0.9998  , df_denom=280, df_num=2
#
# Granger Causality
# number of lags (no zero) 2
# ssr based F test:         F=0.1143  , p=0.8920  , df_denom=280, df_num=2
# ssr based chi2 test:   chi2=0.2328  , p=0.8901  , df=2
# likelihood ratio test: chi2=0.2327  , p=0.8902  , df=2
# parameter F test:         F=0.1143  , p=0.8920  , df_denom=280, df_num=2
#
# Granger Causality
# number of lags (no zero) 1
# ssr based F test:         F=0.0612  , p=0.8048  , df_denom=283, df_num=1
# ssr based chi2 test:   chi2=0.0618  , p=0.8037  , df=1
# likelihood ratio test: chi2=0.0618  , p=0.8037  , df=1
# parameter F test:         F=0.0612  , p=0.8048  , df_denom=283, df_num=1
#
# Granger Causality
# number of lags (no zero) 3
# ssr based F test:         F=1.3006  , p=0.2745  , df_denom=277, df_num=3
# ssr based chi2 test:   chi2=4.0005  , p=0.2614  , df=3
# likelihood ratio test: chi2=3.9726  , p=0.2644  , df=3
# parameter F test:         F=1.3006  , p=0.2745  , df_denom=277, df_num=3
#
# Granger Causality
# number of lags (no zero) 3
# ssr based F test:         F=0.4457  , p=0.7205  , df_denom=277, df_num=3
# ssr based chi2 test:   chi2=1.3709  , p=0.7124  , df=3
# likelihood ratio test: chi2=1.3676  , p=0.7132  , df=3
# parameter F test:         F=0.4457  , p=0.7205  , df_denom=277, df_num=3
#
# Granger Causality
# number of lags (no zero) 5
# ssr based F test:         F=0.5039  , p=0.7732  , df_denom=271, df_num=5
# ssr based chi2 test:   chi2=2.6219  , p=0.7580  , df=5
# likelihood ratio test: chi2=2.6098  , p=0.7599  , df=5
# parameter F test:         F=0.5039  , p=0.7732  , df_denom=271, df_num=5
#
# Granger Causality
# number of lags (no zero) 4
# ssr based F test:         F=0.4953  , p=0.7392  , df_denom=274, df_num=4
# ssr based chi2 test:   chi2=2.0462  , p=0.7273  , df=4
# likelihood ratio test: chi2=2.0388  , p=0.7286  , df=4
# parameter F test:         F=0.4953  , p=0.7392  , df_denom=274, df_num=4
#
# Granger Causality
# number of lags (no zero) 1
# ssr based F test:         F=0.0843  , p=0.7718  , df_denom=283, df_num=1
# ssr based chi2 test:   chi2=0.0852  , p=0.7704  , df=1
# likelihood ratio test: chi2=0.0851  , p=0.7704  , df=1
# parameter F test:         F=0.0843  , p=0.7718  , df_denom=283, df_num=1
#
# Granger Causality
# number of lags (no zero) 3
# ssr based F test:         F=0.3492  , p=0.7897  , df_denom=277, df_num=3
# ssr based chi2 test:   chi2=1.0742  , p=0.7833  , df=3
# likelihood ratio test: chi2=1.0722  , p=0.7838  , df=3
# parameter F test:         F=0.3492  , p=0.7897  , df_denom=277, df_num=3
#
# Granger Causality
# number of lags (no zero) 4
# ssr based F test:         F=0.1591  , p=0.9587  , df_denom=274, df_num=4
# ssr based chi2 test:   chi2=0.6574  , p=0.9565  , df=4
# likelihood ratio test: chi2=0.6566  , p=0.9566  , df=4
# parameter F test:         F=0.1591  , p=0.9587  , df_denom=274, df_num=4
#
# Granger Causality
# number of lags (no zero) 4
# ssr based F test:         F=0.3165  , p=0.8668  , df_denom=274, df_num=4
# ssr based chi2 test:   chi2=1.3076  , p=0.8601  , df=4
# likelihood ratio test: chi2=1.3046  , p=0.8606  , df=4
# parameter F test:         F=0.3165  , p=0.8668  , df_denom=274, df_num=4
#
# Granger Causality
# number of lags (no zero) 2
# ssr based F test:         F=0.3286  , p=0.7202  , df_denom=280, df_num=2
# ssr based chi2 test:   chi2=0.6690  , p=0.7157  , df=2
# likelihood ratio test: chi2=0.6682  , p=0.7160  , df=2
# parameter F test:         F=0.3286  , p=0.7202  , df_denom=280, df_num=2
#
# Granger Causality
# number of lags (no zero) 6
# ssr based F test:         F=0.8058  , p=0.5661  , df_denom=268, df_num=6
# ssr based chi2 test:   chi2=5.0694  , p=0.5349  , df=6
# likelihood ratio test: chi2=5.0242  , p=0.5407  , df=6
# parameter F test:         F=0.8058  , p=0.5661  , df_denom=268, df_num=6
#
# Granger Causality
# number of lags (no zero) 3
# ssr based F test:         F=0.7464  , p=0.5253  , df_denom=277, df_num=3
# ssr based chi2 test:   chi2=2.2957  , p=0.5134  , df=3
# likelihood ratio test: chi2=2.2864  , p=0.5151  , df=3
# parameter F test:         F=0.7464  , p=0.5253  , df_denom=277, df_num=3
#
# Granger Causality
# number of lags (no zero) 4
# ssr based F test:         F=0.2699  , p=0.8972  , df_denom=274, df_num=4
# ssr based chi2 test:   chi2=1.1152  , p=0.8919  , df=4
# likelihood ratio test: chi2=1.1130  , p=0.8922  , df=4
# parameter F test:         F=0.2699  , p=0.8972  , df_denom=274, df_num=4
#
# Granger Causality
# number of lags (no zero) 4
# ssr based F test:         F=0.1856  , p=0.9458  , df_denom=274, df_num=4
# ssr based chi2 test:   chi2=0.7667  , p=0.9429  , df=4
# likelihood ratio test: chi2=0.7657  , p=0.9430  , df=4
# parameter F test:         F=0.1856  , p=0.9458  , df_denom=274, df_num=4
#
# Granger Causality
# number of lags (no zero) 5
# ssr based F test:         F=0.5199  , p=0.7611  , df_denom=271, df_num=5
# ssr based chi2 test:   chi2=2.7052  , p=0.7453  , df=5
# likelihood ratio test: chi2=2.6923  , p=0.7473  , df=5
# parameter F test:         F=0.5199  , p=0.7611  , df_denom=271, df_num=5
#
# Granger Causality
# number of lags (no zero) 3
# ssr based F test:         F=1.8664  , p=0.1355  , df_denom=277, df_num=3
# ssr based chi2 test:   chi2=5.7407  , p=0.1249  , df=3
# likelihood ratio test: chi2=5.6835  , p=0.1281  , df=3
# parameter F test:         F=1.8664  , p=0.1355  , df_denom=277, df_num=3
#
# Granger Causality
# number of lags (no zero) 3
# ssr based F test:         F=1.7456  , p=0.1579  , df_denom=277, df_num=3
# ssr based chi2 test:   chi2=5.3691  , p=0.1467  , df=3
# likelihood ratio test: chi2=5.3190  , p=0.1499  , df=3
# parameter F test:         F=1.7456  , p=0.1579  , df_denom=277, df_num=3
#
# Granger Causality
# number of lags (no zero) 6
# ssr based F test:         F=0.8446  , p=0.5365  , df_denom=268, df_num=6
# ssr based chi2 test:   chi2=5.3133  , p=0.5043  , df=6
# likelihood ratio test: chi2=5.2637  , p=0.5105  , df=6
# parameter F test:         F=0.8446  , p=0.5365  , df_denom=268, df_num=6
#
# Granger Causality
# number of lags (no zero) 7
# ssr based F test:         F=0.1454  , p=0.9944  , df_denom=265, df_num=7
# ssr based chi2 test:   chi2=1.0755  , p=0.9935  , df=7
# likelihood ratio test: chi2=1.0734  , p=0.9936  , df=7
# parameter F test:         F=0.1454  , p=0.9944  , df_denom=265, df_num=7
#
# Granger Causality
# number of lags (no zero) 2
# ssr based F test:         F=0.7804  , p=0.4592  , df_denom=280, df_num=2
# ssr based chi2 test:   chi2=1.5886  , p=0.4519  , df=2
# likelihood ratio test: chi2=1.5842  , p=0.4529  , df=2
# parameter F test:         F=0.7804  , p=0.4592  , df_denom=280, df_num=2
#
# Granger Causality
# number of lags (no zero) 2
# ssr based F test:         F=1.6053  , p=0.2027  , df_denom=280, df_num=2
# ssr based chi2 test:   chi2=3.2679  , p=0.1952  , df=2
# likelihood ratio test: chi2=3.2493  , p=0.1970  , df=2
# parameter F test:         F=1.6053  , p=0.2027  , df_denom=280, df_num=2
#
# Granger Causality
# number of lags (no zero) 1
# ssr based F test:         F=2.6839  , p=0.1025  , df_denom=283, df_num=1
# ssr based chi2 test:   chi2=2.7123  , p=0.0996  , df=1
# likelihood ratio test: chi2=2.6996  , p=0.1004  , df=1
# parameter F test:         F=2.6839  , p=0.1025  , df_denom=283, df_num=1
#
# Granger Causality
# number of lags (no zero) 3
# ssr based F test:         F=0.3515  , p=0.7881  , df_denom=277, df_num=3
# ssr based chi2 test:   chi2=1.0812  , p=0.7816  , df=3
# likelihood ratio test: chi2=1.0792  , p=0.7821  , df=3
# parameter F test:         F=0.3515  , p=0.7881  , df_denom=277, df_num=3
#
# Granger Causality
# number of lags (no zero) 3
# ssr based F test:         F=1.9764  , p=0.1177  , df_denom=277, df_num=3
# ssr based chi2 test:   chi2=6.0790  , p=0.1078  , df=3
# likelihood ratio test: chi2=6.0148  , p=0.1109  , df=3
# ...
# number of lags (no zero) 1
# ssr based F test:         F=1.4271  , p=0.2332  , df_denom=283, df_num=1
# ssr based chi2 test:   chi2=1.4422  , p=0.2298  , df=1
# likelihood ratio test: chi2=1.4386  , p=0.2304  , df=1
# parameter F test:         F=1.4271  , p=0.2332  , df_denom=283, df_num=1
# Granger Causality
# number of lags (no zero) 3
# ssr based F test:         F=1.2150  , p=0.3046  , df_denom=277, df_num=3
# ssr based chi2 test:   chi2=3.7370  , p=0.2913  , df=3
# likelihood ratio test: chi2=3.7126  , p=0.2942  , df=3
# parameter F test:         F=1.2150  , p=0.3046  , df_denom=277, df_num=3
#
# Granger Causality
# number of lags (no zero) 3
# ssr based F test:         F=3.0553  , p=0.0288  , df_denom=277, df_num=3
# ssr based chi2 test:   chi2=9.3975  , p=0.0244  , df=3
# likelihood ratio test: chi2=9.2454  , p=0.0262  , df=3
# parameter F test:         F=3.0553  , p=0.0288  , df_denom=277, df_num=3
#
# Granger Causality
# number of lags (no zero) 5
# ssr based F test:         F=1.2257  , p=0.2972  , df_denom=271, df_num=5
# ssr based chi2 test:   chi2=6.3774  , p=0.2712  , df=5
# likelihood ratio test: chi2=6.3064  , p=0.2775  , df=5
# parameter F test:         F=1.2257  , p=0.2972  , df_denom=271, df_num=5
#
# Granger Causality
# number of lags (no zero) 4
# ssr based F test:         F=0.5132  , p=0.7261  , df_denom=274, df_num=4
# ssr based chi2 test:   chi2=2.1202  , p=0.7137  , df=4
# likelihood ratio test: chi2=2.1123  , p=0.7151  , df=4
# parameter F test:         F=0.5132  , p=0.7261  , df_denom=274, df_num=4
#
# Granger Causality
# number of lags (no zero) 1
# ssr based F test:         F=0.4872  , p=0.4858  , df_denom=283, df_num=1
# ssr based chi2 test:   chi2=0.4923  , p=0.4829  , df=1
# likelihood ratio test: chi2=0.4919  , p=0.4831  , df=1
# parameter F test:         F=0.4872  , p=0.4858  , df_denom=283, df_num=1
#
# Granger Causality
# number of lags (no zero) 3
# ssr based F test:         F=1.5509  , p=0.2016  , df_denom=277, df_num=3
# ssr based chi2 test:   chi2=4.7703  , p=0.1894  , df=3
# likelihood ratio test: chi2=4.7306  , p=0.1926  , df=3
# parameter F test:         F=1.5509  , p=0.2016  , df_denom=277, df_num=3
#
# Granger Causality
# number of lags (no zero) 4
# ssr based F test:         F=0.0758  , p=0.9896  , df_denom=274, df_num=4
# ssr based chi2 test:   chi2=0.3131  , p=0.9890  , df=4
# likelihood ratio test: chi2=0.3129  , p=0.9890  , df=4
# parameter F test:         F=0.0758  , p=0.9896  , df_denom=274, df_num=4
#
# Granger Causality
# number of lags (no zero) 4
# ssr based F test:         F=0.6645  , p=0.6171  , df_denom=274, df_num=4
# ssr based chi2 test:   chi2=2.7455  , p=0.6013  , df=4
# likelihood ratio test: chi2=2.7323  , p=0.6036  , df=4
# parameter F test:         F=0.6645  , p=0.6171  , df_denom=274, df_num=4
#
# Granger Causality
# number of lags (no zero) 6
# ssr based F test:         F=2.2449  , p=0.0394  , df_denom=268, df_num=6
# ssr based chi2 test:   chi2=14.1228 , p=0.0283  , df=6
# likelihood ratio test: chi2=13.7793 , p=0.0322  , df=6
# parameter F test:         F=2.2449  , p=0.0394  , df_denom=268, df_num=6
#
# Granger Causality
# number of lags (no zero) 3
# ssr based F test:         F=2.2284  , p=0.0851  , df_denom=277, df_num=3
# ssr based chi2 test:   chi2=6.8542  , p=0.0767  , df=3
# likelihood ratio test: chi2=6.7728  , p=0.0795  , df=3
# parameter F test:         F=2.2284  , p=0.0851  , df_denom=277, df_num=3
#
# Granger Causality
# number of lags (no zero) 4
# ssr based F test:         F=2.4510  , p=0.0464  , df_denom=274, df_num=4
# ssr based chi2 test:   chi2=10.1262 , p=0.0384  , df=4
# likelihood ratio test: chi2=9.9492  , p=0.0413  , df=4
# parameter F test:         F=2.4510  , p=0.0464  , df_denom=274, df_num=4
#
# Granger Causality
# number of lags (no zero) 4
# ssr based F test:         F=0.0993  , p=0.9826  , df_denom=274, df_num=4
# ssr based chi2 test:   chi2=0.4102  , p=0.9816  , df=4
# likelihood ratio test: chi2=0.4099  , p=0.9817  , df=4
# parameter F test:         F=0.0993  , p=0.9826  , df_denom=274, df_num=4
#
# Granger Causality
# number of lags (no zero) 5
# ssr based F test:         F=0.7617  , p=0.5781  , df_denom=271, df_num=5
# ssr based chi2 test:   chi2=3.9631  , p=0.5547  , df=5
# likelihood ratio test: chi2=3.9355  , p=0.5587  , df=5
# parameter F test:         F=0.7617  , p=0.5781  , df_denom=271, df_num=5
#
# Granger Causality
# number of lags (no zero) 3
# ssr based F test:         F=0.7221  , p=0.5395  , df_denom=277, df_num=3
# ssr based chi2 test:   chi2=2.2210  , p=0.5278  , df=3
# likelihood ratio test: chi2=2.2124  , p=0.5295  , df=3
# parameter F test:         F=0.7221  , p=0.5395  , df_denom=277, df_num=3
#
# Granger Causality
# number of lags (no zero) 3
# ssr based F test:         F=0.7617  , p=0.5164  , df_denom=277, df_num=3
# ssr based chi2 test:   chi2=2.3428  , p=0.5044  , df=3
# likelihood ratio test: chi2=2.3332  , p=0.5062  , df=3
# parameter F test:         F=0.7617  , p=0.5164  , df_denom=277, df_num=3
#
# Granger Causality
# number of lags (no zero) 6
# ssr based F test:         F=1.3698  , p=0.2269  , df_denom=268, df_num=6
# ssr based chi2 test:   chi2=8.6177  , p=0.1962  , df=6
# likelihood ratio test: chi2=8.4882  , p=0.2045  , df=6
# parameter F test:         F=1.3698  , p=0.2269  , df_denom=268, df_num=6
#
# Granger Causality
# number of lags (no zero) 7
# ssr based F test:         F=0.2930  , p=0.9563  , df_denom=265, df_num=7
# ssr based chi2 test:   chi2=2.1673  , p=0.9500  , df=7
# likelihood ratio test: chi2=2.1590  , p=0.9505  , df=7
# parameter F test:         F=0.2930  , p=0.9563  , df_denom=265, df_num=7
#
# Granger Causality
# number of lags (no zero) 3
# ssr based F test:         F=0.4535  , p=0.7150  , df_denom=277, df_num=3
# ssr based chi2 test:   chi2=1.3949  , p=0.7067  , df=3
# likelihood ratio test: chi2=1.3915  , p=0.7075  , df=3
# parameter F test:         F=0.4535  , p=0.7150  , df_denom=277, df_num=3
#
# Granger Causality
# number of lags (no zero) 2
# ssr based F test:         F=0.5812  , p=0.5599  , df_denom=280, df_num=2
# ssr based chi2 test:   chi2=1.1832  , p=0.5534  , df=2
# likelihood ratio test: chi2=1.1807  , p=0.5541  , df=2
# parameter F test:         F=0.5812  , p=0.5599  , df_denom=280, df_num=2
#
# Granger Causality
# number of lags (no zero) 2
# ssr based F test:         F=2.4238  , p=0.0904  , df_denom=280, df_num=2
# ssr based chi2 test:   chi2=4.9342  , p=0.0848  , df=2
# likelihood ratio test: chi2=4.8920  , p=0.0866  , df=2
# parameter F test:         F=2.4238  , p=0.0904  , df_denom=280, df_num=2
#
# Granger Causality
# number of lags (no zero) 1
# ssr based F test:         F=0.0233  , p=0.8788  , df_denom=283, df_num=1
# ssr based chi2 test:   chi2=0.0235  , p=0.8780  , df=1
# likelihood ratio test: chi2=0.0235  , p=0.8780  , df=1
# parameter F test:         F=0.0233  , p=0.8788  , df_denom=283, df_num=1
#
# Granger Causality
# number of lags (no zero) 3
# ssr based F test:         F=0.2506  , p=0.8609  , df_denom=277, df_num=3
# ssr based chi2 test:   chi2=0.7707  , p=0.8565  , df=3
# likelihood ratio test: chi2=0.7697  , p=0.8567  , df=3
# parameter F test:         F=0.2506  , p=0.8609  , df_denom=277, df_num=3
#
# Granger Causality
# number of lags (no zero) 3
# ssr based F test:         F=3.0971  , p=0.0273  , df_denom=277, df_num=3
# ssr based chi2 test:   chi2=9.5262  , p=0.0231  , df=3
# likelihood ratio test: chi2=9.3699  , p=0.0248  , df=3
# parameter F test:         F=3.0971  , p=0.0273  , df_denom=277, df_num=3
#
# Granger Causality
# number of lags (no zero) 5
# ssr based F test:         F=0.6765  , p=0.6416  , df_denom=271, df_num=5
# ssr based chi2 test:   chi2=3.5198  , p=0.6204  , df=5
# likelihood ratio test: chi2=3.4981  , p=0.6237  , df=5
# parameter F test:         F=0.6765  , p=0.6416  , df_denom=271, df_num=5
#
# Granger Causality
# number of lags (no zero) 4
# ssr based F test:         F=1.6412  , p=0.1641  , df_denom=274, df_num=4
# ssr based chi2 test:   chi2=6.7803  , p=0.1480  , df=4
# likelihood ratio test: chi2=6.7004  , p=0.1526  , df=4
# parameter F test:         F=1.6412  , p=0.1641  , df_denom=274, df_num=4
#
# Granger Causality
# number of lags (no zero) 1
# ssr based F test:         F=1.8629  , p=0.1734  , df_denom=283, df_num=1
# ssr based chi2 test:   chi2=1.8826  , p=0.1700  , df=1
# likelihood ratio test: chi2=1.8764  , p=0.1707  , df=1
# parameter F test:         F=1.8629  , p=0.1734  , df_denom=283, df_num=1
#
# Granger Causality
# number of lags (no zero) 3
# ssr based F test:         F=0.0731  , p=0.9744  , df_denom=277, df_num=3
# ssr based chi2 test:   chi2=0.2248  , p=0.9735  , df=3
# likelihood ratio test: chi2=0.2247  , p=0.9735  , df=3
# parameter F test:         F=0.0731  , p=0.9744  , df_denom=277, df_num=3
#
# Granger Causality
# number of lags (no zero) 4
# ssr based F test:         F=0.3473  , p=0.8458  , df_denom=274, df_num=4
# ssr based chi2 test:   chi2=1.4350  , p=0.8381  , df=4
# likelihood ratio test: chi2=1.4314  , p=0.8387  , df=4
# parameter F test:         F=0.3473  , p=0.8458  , df_denom=274, df_num=4
#
# Granger Causality
# number of lags (no zero) 4
# ssr based F test:         F=0.2403  , p=0.9154  , df_denom=274, df_num=4
# ssr based chi2 test:   chi2=0.9926  , p=0.9109  , df=4
# likelihood ratio test: chi2=0.9909  , p=0.9112  , df=4
# parameter F test:         F=0.2403  , p=0.9154  , df_denom=274, df_num=4
#
# Granger Causality
# number of lags (no zero) 2
# ssr based F test:         F=0.3555  , p=0.7011  , df_denom=280, df_num=2
# ssr based chi2 test:   chi2=0.7238  , p=0.6964  , df=2
# likelihood ratio test: chi2=0.7229  , p=0.6967  , df=2
# parameter F test:         F=0.3555  , p=0.7011  , df_denom=280, df_num=2
#
# Granger Causality
# number of lags (no zero) 3
# ssr based F test:         F=1.6583  , p=0.1763  , df_denom=277, df_num=3
# ssr based chi2 test:   chi2=5.1005  , p=0.1646  , df=3
# likelihood ratio test: chi2=5.0553  , p=0.1678  , df=3
# parameter F test:         F=1.6583  , p=0.1763  , df_denom=277, df_num=3
#
# Granger Causality
# number of lags (no zero) 4
# ssr based F test:         F=0.4396  , p=0.7799  , df_denom=274, df_num=4
# ssr based chi2 test:   chi2=1.8162  , p=0.7695  , df=4
# likelihood ratio test: chi2=1.8104  , p=0.7706  , df=4
# parameter F test:         F=0.4396  , p=0.7799  , df_denom=274, df_num=4
#
# Granger Causality
# number of lags (no zero) 4
# ssr based F test:         F=1.1783  , p=0.3206  , df_denom=274, df_num=4
# ssr based chi2 test:   chi2=4.8681  , p=0.3011  , df=4
# likelihood ratio test: chi2=4.8267  , p=0.3055  , df=4
# parameter F test:         F=1.1783  , p=0.3206  , df_denom=274, df_num=4
#
# Granger Causality
# number of lags (no zero) 5
# ssr based F test:         F=1.2413  , p=0.2900  , df_denom=271, df_num=5
# ssr based chi2 test:   chi2=6.4584  , p=0.2641  , df=5
# likelihood ratio test: chi2=6.3856  , p=0.2705  , df=5
# parameter F test:         F=1.2413  , p=0.2900  , df_denom=271, df_num=5
#
# Granger Causality
# number of lags (no zero) 3
# ssr based F test:         F=3.7796  , p=0.0110  , df_denom=277, df_num=3
# ssr based chi2 test:   chi2=11.6254 , p=0.0088  , df=3
# likelihood ratio test: chi2=11.3938 , p=0.0098  , df=3
# parameter F test:         F=3.7796  , p=0.0110  , df_denom=277, df_num=3
#
# Granger Causality
# number of lags (no zero) 3
# ssr based F test:         F=1.6809  , p=0.1713  , df_denom=277, df_num=3
# ssr based chi2 test:   chi2=5.1702  , p=0.1597  , df=3
# likelihood ratio test: chi2=5.1237  , p=0.1630  , df=3
# parameter F test:         F=1.6809  , p=0.1713  , df_denom=277, df_num=3
#
# Granger Causality
# number of lags (no zero) 6
# ssr based F test:         F=0.6611  , p=0.6812  , df_denom=268, df_num=6
# ssr based chi2 test:   chi2=4.1590  , p=0.6552  , df=6
# likelihood ratio test: chi2=4.1285  , p=0.6593  , df=6
# parameter F test:         F=0.6611  , p=0.6812  , df_denom=268, df_num=6
#
# Granger Causality
# number of lags (no zero) 7
# ssr based F test:         F=0.4203  , p=0.8893  , df_denom=265, df_num=7
# ssr based chi2 test:   chi2=3.1086  , p=0.8748  , df=7
# likelihood ratio test: chi2=3.0914  , p=0.8764  , df=7
# parameter F test:         F=0.4203  , p=0.8893  , df_denom=265, df_num=7
#
# Granger Causality
# number of lags (no zero) 3
# ssr based F test:         F=0.3346  , p=0.8003  , df_denom=277, df_num=3
# ssr based chi2 test:   chi2=1.0292  , p=0.7942  , df=3
# likelihood ratio test: chi2=1.0273  , p=0.7946  , df=3
# parameter F test:         F=0.3346  , p=0.8003  , df_denom=277, df_num=3
#
# Granger Causality
# number of lags (no zero) 2
# ssr based F test:         F=1.8044  , p=0.1665  , df_denom=280, df_num=2
# ssr based chi2 test:   chi2=3.6732  , p=0.1594  , df=2
# likelihood ratio test: chi2=3.6498  , p=0.1612  , df=2
# parameter F test:         F=1.8044  , p=0.1665  , df_denom=280, df_num=2
#
# Granger Causality
# number of lags (no zero) 2
# ssr based F test:         F=0.1812  , p=0.8343  , df_denom=280, df_num=2
# ssr based chi2 test:   chi2=0.3690  , p=0.8315  , df=2
# likelihood ratio test: chi2=0.3687  , p=0.8316  , df=2
# parameter F test:         F=0.1812  , p=0.8343  , df_denom=280, df_num=2
#
# Granger Causality
# number of lags (no zero) 1
# ssr based F test:         F=2.9441  , p=0.0873  , df_denom=283, df_num=1
# ssr based chi2 test:   chi2=2.9754  , p=0.0845  , df=1
# likelihood ratio test: chi2=2.9600  , p=0.0853  , df=1
# parameter F test:         F=2.9441  , p=0.0873  , df_denom=283, df_num=1
#
# Granger Causality
# number of lags (no zero) 3
# ssr based F test:         F=0.0600  , p=0.9807  , df_denom=277, df_num=3
# ssr based chi2 test:   chi2=0.1847  , p=0.9800  , df=3
# likelihood ratio test: chi2=0.1846  , p=0.9800  , df=3
# parameter F test:         F=0.0600  , p=0.9807  , df_denom=277, df_num=3
#
# Granger Causality
# number of lags (no zero) 3
# ssr based F test:         F=0.0426  , p=0.9883  , df_denom=277, df_num=3
# ssr based chi2 test:   chi2=0.1311  , p=0.9879  , df=3
# likelihood ratio test: chi2=0.1311  , p=0.9879  , df=3
# parameter F test:         F=0.0426  , p=0.9883  , df_denom=277, df_num=3
#
# Granger Causality
# number of lags (no zero) 5
# ssr based F test:         F=0.5199  , p=0.7612  , df_denom=271, df_num=5
# ssr based chi2 test:   chi2=2.7049  , p=0.7454  , df=5
# likelihood ratio test: chi2=2.6921  , p=0.7473  , df=5
# parameter F test:         F=0.5199  , p=0.7612  , df_denom=271, df_num=5
#
# Granger Causality
# number of lags (no zero) 4
# ssr based F test:         F=1.5134  , p=0.1984  , df_denom=274, df_num=4
# ssr based chi2 test:   chi2=6.2526  , p=0.1811  , df=4
# likelihood ratio test: chi2=6.1846  , p=0.1858  , df=4
# parameter F test:         F=1.5134  , p=0.1984  , df_denom=274, df_num=4
#
# Granger Causality
# number of lags (no zero) 1
# ssr based F test:         F=1.0966  , p=0.2959  , df_denom=283, df_num=1
# ssr based chi2 test:   chi2=1.1082  , p=0.2925  , df=1
# likelihood ratio test: chi2=1.1061  , p=0.2929  , df=1
# parameter F test:         F=1.0966  , p=0.2959  , df_denom=283, df_num=1
#
# Granger Causality
# number of lags (no zero) 3
# ssr based F test:         F=0.6323  , p=0.5948  , df_denom=277, df_num=3
# ssr based chi2 test:   chi2=1.9447  , p=0.5840  , df=3
# likelihood ratio test: chi2=1.9381  , p=0.5854  , df=3
# parameter F test:         F=0.6323  , p=0.5948  , df_denom=277, df_num=3
# Granger Causality
# number of lags (no zero) 4
# ssr based F test:         F=0.7069  , p=0.5878  , df_denom=274, df_num=4
# ssr based chi2 test:   chi2=2.9206  , p=0.5712  , df=4
# likelihood ratio test: chi2=2.9056  , p=0.5737  , df=4
# parameter F test:         F=0.7069  , p=0.5878  , df_denom=274, df_num=4
#
# Granger Causality
# number of lags (no zero) 4
# ssr based F test:         F=1.4225  , p=0.2267  , df_denom=274, df_num=4
# ssr based chi2 test:   chi2=5.8770  , p=0.2085  , df=4
# likelihood ratio test: chi2=5.8168  , p=0.2133  , df=4
# parameter F test:         F=1.4225  , p=0.2267  , df_denom=274, df_num=4
#
# Granger Causality
# number of lags (no zero) 2
# ssr based F test:         F=3.3015  , p=0.0383  , df_denom=280, df_num=2
# ssr based chi2 test:   chi2=6.7209  , p=0.0347  , df=2
# likelihood ratio test: chi2=6.6429  , p=0.0361  , df=2
# parameter F test:         F=3.3015  , p=0.0383  , df_denom=280, df_num=2
#
# Granger Causality
# number of lags (no zero) 6
# ssr based F test:         F=0.8928  , p=0.5005  , df_denom=268, df_num=6
# ssr based chi2 test:   chi2=5.6169  , p=0.4674  , df=6
# likelihood ratio test: chi2=5.5615  , p=0.4741  , df=6
# parameter F test:         F=0.8928  , p=0.5005  , df_denom=268, df_num=6

# %%
dd
# Out:
# {'Convention Center': ['Indoor Entertainment',
#   'Office',
#   'Residence',
#   'Store, Market & Fair',
#   'Transportation',
#   'Travel-Related Place'],
#  'Electronics': ['General Education Place',
#   'Indoor Entertainment',
#   'Medical-Related Place',
#   'Office',
#   'Smoke Shop',
#   'Store, Market & Fair',
#   'Travel-Related Place'],
#  'Factory': ['Convention Center',
#   'Food & Snack',
#   'Residence',
#   'School',
#   'Transportation',
#   'Travel-Related Place',
#   'Vehicle-Related Place'],
#  'Food & Snack': ['Convention Center',
#   'History, Museum & Arts',
#   'Outdoor Entertainment',
#   'Restaurant',
#   'School',
#   'Store, Market & Fair',
#   'Transportation',
#   'Travel-Related Place'],
#  'General Education Place': ['Factory',
#   'Hotel',
#   'Indoor Entertainment',
#   'Medical-Related Place',
#   'School',
#   'Smoke Shop',
#   'Travel-Related Place'],
#  'History, Museum & Arts': ['Convention Center',
#   'Factory',
#   'Residence',
#   'School'],
#  'Hotel': ['Factory'],
#  'Indoor Entertainment': ['Food & Snack',
#   'Office',
#   'Place for Sports',
#   'School',
#   'Smoke Shop'],
#  'Medical-Related Place': ['Factory',
#   'General Education Place',
#   'Rest Area',
#   'Travel-Related Place'],
#  'Neighborhood': ['Food & Snack',
#   'History, Museum & Arts',
#   'Place for Sports',
#   'Restaurant',
#   'Store, Market & Fair',
#   'Transportation'],
#  'Office': ['Factory',
#   'Hotel',
#   'Medical-Related Place',
#   'Place for Sports',
#   'Residence',
#   'Vehicle-Related Place'],
#  'Outdoor Entertainment': ['Place for Sports', 'Travel-Related Place'],
#  'Place for Sports': ['Convention Center',
#   'Office',
#   'Outdoor Entertainment',
#   'Rest Area',
#   'Travel-Related Place'],
#  'Residence': ['Factory',
#   'Food & Snack',
#   'History, Museum & Arts',
#   'Indoor Entertainment',
#   'Outdoor Entertainment',
#   'Place for Sports',
#   'School',
#   'Travel-Related Place'],
#  'Rest Area': ['Convention Center', 'Vehicle-Related Place'],
#  'Restaurant': ['History, Museum & Arts',
#   'Store, Market & Fair',
#   'Vehicle-Related Place'],
#  'School': ['General Education Place',
#   'Hotel',
#   'Office',
#   'Residence',
#   'Store, Market & Fair',
#   'Transportation',
#   'Travel-Related Place'],
#  'Smoke Shop': ['Indoor Entertainment', 'School'],
#  'Store, Market & Fair': ['Electronics',
#   'Food & Snack',
#   'General Education Place',
#   'Neighborhood',
#   'Outdoor Entertainment',
#   'Residence',
#   'Rest Area',
#   'Transportation'],
#  'Transportation': ['Place for Sports',
#   'Travel-Related Place',
#   'Vehicle-Related Place'],
#  'Travel-Related Place': ['Convention Center',
#   'Neighborhood',
#   'Place for Sports'],
#  'Vehicle-Related Place': ['Food & Snack', 'Office', 'Transportation']}

# %%
causes = ['Food & Snack', 'Office', 'Transportation']
y = 'Vehicle-Related Place'
dff = pd.DataFrame()
for pattern in causes:
    x = np.array(data_colo[pattern])
    x = x[1:]-x[:-1]
    dff[pattern] = x
t = np.array(data_colo[y])
t = t[1:] - t[:-1]
dff[y] = t

# %%
dff.head()
# Out:
#    Food & Snack  Office  Transportation  Vehicle-Related Place
# 0          14.0     3.0            -2.0                    6.0
# 1           1.0     4.0           -20.0                    1.0
# 2          11.0    -3.0             9.0                    2.0
# 3         -10.0     2.0             0.0                   -5.0
# 4          -9.0     0.0           -18.0                   -4.0

# %%
dff.shape
# Out:
# (287, 4)

# %%
dff.to_csv("./dataset_tsmc2014/convention_center.csv")
