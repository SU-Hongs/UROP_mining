# %%
import pandas as pd

data=pd.read_csv('dataset_tsmc2014.num_colo.csv')
data=data.drop(data.columns[[0]],axis=1)
data.head()
# Out:
#    Convention Center  Electronics  Factory  Food & Snack  \
# 0                3.0          7.0      1.0          61.0
# 1                1.0          4.0      1.0          75.0
# 2                2.0          4.0      0.0          76.0
# 3                1.0          7.0      0.0          87.0
# 4                1.0          7.0      0.0          77.0
#
#    General Education Place  History, Museum & Arts  Hotel  \
# 0                      6.0                    29.0   19.0
# 1                      4.0                    25.0   19.0
# 2                      2.0                    26.0   22.0
# 3                      6.0                    18.0   19.0
# 4                      1.0                    22.0   26.0
#
#    Indoor Entertainment  Medical-Related Place  Neighborhood  ...  \
# 0                 234.0                   19.0          22.0  ...
# 1                 211.0                   24.0          33.0  ...
# 2                 185.0                   20.0          30.0  ...
# ...

# %%
from causalnex.structure.notears import from_pandas

struct_data=data.copy()
sm=from_pandas(struct_data)
sm

# %%
from causalnex.plots import plot_structure
import networkx as nx
import matplotlib.pyplot as plt

sm_thres=sm.copy()
sm_thres.remove_edges_below_threshold(1.5)


viz=plot_structure(sm_thres,graph_attributes={'scale':'2'},all_node_attributes={'fontsize':6})

viz.draw(format='png',path='./causalnet_output.png')

# nx.draw(G, cmap = plt.get_cmap('jet'), node_color = values)
# plt.show()
# Out:
# c:\Users\William\anaconda3\envs\causal\lib\site-packages\pygraphviz\agraph.py:1402: RuntimeWarning: Warning: node 'Convention Center', graph '' size too small for label
# ...
#
#   warnings.warn(b"".join(errors).decode(self.encoding), RuntimeWarning)
